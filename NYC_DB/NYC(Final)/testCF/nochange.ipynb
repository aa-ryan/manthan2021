# %%
import csv
import math
def areawise(freqfile,percentfile):
    csvfile = open(percentfile, newline='')
    csvAvg = open(freqfile,newline='')
    
    c = csv.reader(csvfile)
    d = csv.reader(csvAvg)
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    average=[0] * 71  # change to higher value to make it non-redundant for now it is equal to the no of total unique crimes
    i=0
    yearsToTrain = 14    # change s value to no of years to be used for training 
    
    for row in d:
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year' or row[0]=='month':
            continue
        else:
           j=0
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
                   average[i] += float(row[month])    # maintain grand average for scale later 
           if average[i] != 0:
                average[i] /= j
           i+=1
          
    percentages = []
    totals = []
    categories =[]
    i = 0
    monYear = []
    
    for row in c:
        
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year':
            continue
        elif row[0]=='month':
            for month in range(1,(yearsToTrain*12)+1):
                monYear.append(float(row[month]))
        else:
           temp = []
           categories.append(row[0])
           
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
               
               temp.append(float(row[month]))   # add monthly percentages of a particular crime to  list 
           
           percentages.append(temp)   # add monthly percentages list to a list 
           i += 1
    
    # print("percentages here :")
    # print(percentages)
    predictions=[]


    def predictOverYears(start,end):           # fn to give prediction for one year mentioned by start and end
        predictAyear = []
        for idx in range (0,i):
            crime = percentages[idx]
            sum =0
            index = -1
            for it in range (start,end):     # sum for caluclationg confidence later on             
                sum+=crime[it]
        
            predictMonth = []
    
            for it in range (start,end):
                avg = sum - crime[it]
                avg=float(avg/11)
                if avg != 0:
                    likeness = ((float(crime[it])/(avg))) * 100    # measure confidence rate for that month for that crime
                else :
                    likeness=0
                temp = [likeness,monYear[it]]
                predictMonth.append(temp)                   # append confidence rate and index of month predicted
    
            predictAyear.append(predictMonth)           # append all month's of that year likliness to a list 
        return predictAyear


    for j in range(0,yearsToTrain):            
        n=j*12
        predictions.append(predictOverYears(n,n+12))
    
    # print(predictions[1])
    # print("predictions here :")
    # print(predictions)
    
    predictionPerCrime = []
    for idx in range(0,i):
        tem = []
        for k in range(0,yearsToTrain):
            tem.append(predictions[k][idx])           # get each individual year predictions and add it to a new list 
        predictionPerCrime.append(tem)
        
    
    # print("prediction per crime:")
    # print(predictionPerCrime[0])


    grandPrediction = []
    for idx in range(0,i):
        perCrimeConf=[]
        for month in range(0,12):
            sumOverYears=0
            for yr in range(0,yearsToTrain):
                sumOverYears+=predictionPerCrime[idx][yr][month][0]
            tem=sumOverYears/yearsToTrain   # sum of confidence of a month across years and divide by yearsToTrain
            perCrimeConf.append(tem)
        grandPrediction.append(perCrimeConf)  # append confidence rates of each month per crime to list 

    
    # print("grand prediction: ")
    # print(grandPrediction)
    # print(grandPrediction[0][2])
    
    for j in range(0,i):
        low=9999
        for m in range(0,12):
            if grandPrediction[j][m] < low:
                low = grandPrediction[j][m]
        if low != 0 :
             low = math.ceil(low) -2  # find lowest value ceil it and subtrat 2 from it
        for n in range(0,12):
            grandPrediction[j][n] -= low  # then subtract this val(low) from all
    
    # print("grand predictions: ")
    # print(grandPrediction)

    print("{")
    print('\"'+freqfile.split('_')[0]+'\":')
    print("[")
    
    for j in range(0,6):
        print('{')
        print('\"'+"crime"+'\":'+'\"'+categories[j]+'\",')
        max = 0
        avg = 0
        for m in range (0,12):
             avg+=grandPrediction[j][m]
             if grandPrediction[j][m] > max :
                 max = grandPrediction[j][m]
        avg=avg/12
        ideal = ( max + avg)/2     # compute ideal confidence and acceptable confidence level
        print('\"'+"overallAverage"+'\":'+'\"'+str(average[j])+'\",')
        print('\"'+"idealConfidence"+'\":'+'\"'+str(ideal)+'\",')
        print('\"'+"accepatableConfidence"+'\":'+'\"'+str(avg)+'\",')
        print('\"'+"confidenceRates"+'\":'+'[')
        print('{')
        for k in range(0,12):
            if k != 11:
                print('\"'+months[k]+'\":'+'\"'+str(grandPrediction[j][k])+'\",')
            else:
                print('\"'+months[k]+'\":'+'\"'+str(grandPrediction[j][k])+'\"')
        # print(j+1,")",categories[j],"With overall average:",average[j])
        # print("With ideal confidence:",ideal,"and acceptable confidence:",avg,"monthly predictons are:")
        # for k in range(0,12):
        #     print("     Month",k+1,"confidence rate:",grandPrediction[j][k]) 
        print('}')  
        print(']')
        if j!=i-1:
            print('},')
        else:
            print('}')
                 
    print(']')
    print('}')

areawise('BRONX_Frequency.csv','BRONX_PercentageTotal.csv')
areawise('BROOKLYN_Frequency.csv','BROOKLYN_PercentageTotal.csv')
areawise('MANHATTAN_Frequency.csv','MANHATTAN_PercentageTotal.csv')
areawise('QUEENS_Frequency.csv','QUEENS_PercentageTotal.csv')
areawise('STATEN_ISLAND_Frequency.csv','STATEN_ISLAND_PercentageTotal.csv')
# Out:
# {
# "BRONX":
# [
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1145.9345238095239",
# "idealConfidence":"8.895779490453231",
# "accepatableConfidence":"7.025592118516644",
# "confidenceRates":[
# {
# "Jan":"5.17650569023499",
# "Feb":"3.4070378063325535",
# "Mar":"6.598562484788545",
# "Apr":"7.890241082144712",
# "May":"10.35270529562375",
# "Jun":"10.460208194904226",
# "Jul":"6.041754179988814",
# "Aug":"1.6215842509570848",
# "Sep":"10.765966862389817",
# "Oct":"8.841792733366319",
# "Nov":"5.97855670383926",
# "Dec":"7.172190137629656"
# }
# ]
# },
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"1191.125",
# "idealConfidence":"14.222823200892229",
# "accepatableConfidence":"11.039392645528805",
# "confidenceRates":[
# {
# "Jan":"9.096441460113525",
# "Feb":"1.8208860853705175",
# "Mar":"3.365134258098095",
# "Apr":"6.897539827386964",
# "May":"10.045222945585792",
# "Jun":"12.900148112177334",
# "Jul":"12.589187355251838",
# "Aug":"14.766908410072531",
# "Sep":"15.164436626013895",
# "Oct":"14.693462686380599",
# "Nov":"13.72709022363891",
# "Dec":"17.40625375625565"
# }
# ]
# },
# {
# "crime":"DANGEROUS DRUGS",
# "overallAverage":"928.0059523809524",
# "idealConfidence":"28.993078136024014",
# "accepatableConfidence":"20.15728289473207",
# "confidenceRates":[
# {
# "Jan":"30.103226557524536",
# "Feb":"37.82887337731596",
# "Mar":"27.679022833872907",
# "Apr":"24.363246664065713",
# "May":"18.079407021483817",
# "Jun":"10.509481295828621",
# "Jul":"12.686034205190907",
# "Aug":"22.595220873879057",
# "Sep":"22.319572005755916",
# "Oct":"19.92971310888069",
# "Nov":"13.884692440724521",
# "Dec":"1.9089043522621694"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"1079.6964285714287",
# "idealConfidence":"9.240142399320266",
# "accepatableConfidence":"6.028352622361944",
# "confidenceRates":[
# {
# "Jan":"1.0210475679751454",
# "Feb":"5.5941580965808555",
# "Mar":"8.151572411452307",
# "Apr":"7.871498976724737",
# "May":"12.45193217627859",
# "Jun":"12.21012708999534",
# "Jul":"9.620469756441011",
# "Aug":"5.003518799465141",
# "Sep":"5.250319122885813",
# "Oct":"1.1981188009444708",
# "Nov":"2.1553986808564503",
# "Dec":"1.812069988743474"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"872.1904761904761",
# "idealConfidence":"8.943942782245161",
# "accepatableConfidence":"6.046678636609033",
# "confidenceRates":[
# {
# "Jan":"5.834716916270295",
# "Feb":"1.8788263038338897",
# "Mar":"10.991736903395108",
# "Apr":"11.841206927881288",
# "May":"8.745289257189711",
# "Jun":"7.971022257206883",
# "Jul":"6.76320220434549",
# "Aug":"5.665941741939761",
# "Sep":"4.099225811872401",
# "Oct":"2.1089505015517176",
# "Nov":"4.651576310706361",
# "Dec":"2.0084485031154884"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"483.2440476190476",
# "idealConfidence":"14.280799693690312",
# "accepatableConfidence":"9.109378142397771",
# "confidenceRates":[
# {
# "Jan":"16.695965957331097",
# "Feb":"14.461768631529324",
# "Mar":"19.45222124498285",
# "Apr":"16.521524446815462",
# "May":"6.505039384212054",
# "Jun":"4.675698327256512",
# "Jul":"1.5181855145305434",
# "Aug":"7.791860937623127",
# "Sep":"7.449918251892328",
# "Oct":"3.655963448529633",
# "Nov":"4.95248076244134",
# "Dec":"5.63191080162899"
# }
# ]
# },
# ]
# }
# {
# "BROOKLYN":
# [
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"1918.5654761904761",
# "idealConfidence":"13.995259927141905",
# "accepatableConfidence":"11.036423616288454",
# "confidenceRates":[
# {
# "Jan":"8.340669743091624",
# "Feb":"1.1285348675049676",
# "Mar":"2.660221699487323",
# "Apr":"6.152621413988825",
# "May":"9.604885208933936",
# "Jun":"13.836825827540494",
# "Jul":"16.95409623799536",
# "Aug":"16.383765144614557",
# "Sep":"14.052789911142938",
# "Oct":"13.737770712143202",
# "Nov":"13.329372767769101",
# "Dec":"16.255529861249144"
# }
# ]
# },
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1563.9107142857142",
# "idealConfidence":"7.292509892077129",
# "accepatableConfidence":"5.020781354945359",
# "confidenceRates":[
# {
# "Jan":"2.0313241321530455",
# "Feb":"2.3963758818026974",
# "Mar":"3.5051196193447396",
# "Apr":"3.9677914429578465",
# "May":"7.435669720393292",
# "Jun":"9.564238429208899",
# "Jul":"7.484086050057826",
# "Aug":"5.580374080908385",
# "Sep":"8.462244472526308",
# "Oct":"4.727112990045697",
# "Nov":"3.4475239484961406",
# "Dec":"1.6475154914494254"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"1355.3630952380952",
# "idealConfidence":"10.850199726271866",
# "accepatableConfidence":"7.032229625937343",
# "confidenceRates":[
# {
# "Jan":"2.9291399007094157",
# "Feb":"4.980871862318438",
# "Mar":"9.211345214611896",
# "Apr":"7.598198087914938",
# "May":"13.898336479095619",
# "Jun":"14.668169826606388",
# "Jul":"12.610945940189055",
# "Aug":"7.169523626942436",
# "Sep":"6.213892837633935",
# "Oct":"1.8186875970011585",
# "Nov":"1.0738895823498211",
# "Dec":"2.2137545558750134"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"1281.7559523809523",
# "idealConfidence":"9.847878691482176",
# "accepatableConfidence":"7.046561041699058",
# "confidenceRates":[
# {
# "Jan":"6.7706700638723305",
# "Feb":"5.664090509686702",
# "Mar":"12.649196341265295",
# "Apr":"8.380960793510425",
# "May":"8.097068828098642",
# "Jun":"8.863181537881616",
# "Jul":"9.619266256422563",
# "Aug":"4.361354285987673",
# "Sep":"4.698464763327209",
# "Oct":"5.767421834875904",
# "Nov":"8.589330478243127",
# "Dec":"1.0977268072172137"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"951.1428571428571",
# "idealConfidence":"13.35618068794984",
# "accepatableConfidence":"9.04441941080876",
# "confidenceRates":[
# {
# "Jan":"5.5723142713913205",
# "Feb":"1.113843094642263",
# "Mar":"1.9317931224504576",
# "Apr":"2.780076124233318",
# "May":"3.922432168199151",
# "Jun":"9.988437561249654",
# "Jul":"12.99163783652385",
# "Aug":"11.962904765371448",
# "Sep":"11.901877801632807",
# "Oct":"13.380637086006587",
# "Nov":"15.319137132913355",
# "Dec":"17.667941965090918"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"656.0297619047619",
# "idealConfidence":"12.72991206189372",
# "accepatableConfidence":"8.100628320152676",
# "confidenceRates":[
# {
# "Jan":"13.803434903350563",
# "Feb":"16.76006514209277",
# "Mar":"17.359195803634762",
# "Apr":"16.505121820044323",
# "May":"8.756999882924475",
# "Jun":"3.6811691292614626",
# "Jul":"2.9476304726640308",
# "Aug":"3.908106119917747",
# "Sep":"3.5185487858803555",
# "Oct":"1.3607609869128083",
# "Nov":"3.9064962714610374",
# "Dec":"4.70001052368778"
# }
# ]
# },
# ]
# }
# {
# "MANHATTAN":
# [
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"2174.8690476190477",
# "idealConfidence":"10.721505121702094",
# "accepatableConfidence":"8.022015232708513",
# "confidenceRates":[
# {
# "Jan":"5.2452654975155895",
# "Feb":"3.293547978999314",
# "Mar":"1.5645152285981538",
# "Apr":"4.461057460373894",
# "May":"5.613113884018475",
# "Jun":"9.241180483253288",
# "Jul":"11.613743768477065",
# "Aug":"13.420995010695677",
# "Sep":"12.489192709182106",
# "Oct":"7.985584887345553",
# "Nov":"8.634614297079466",
# "Dec":"12.701371586963589"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"1386.3869047619048",
# "idealConfidence":"19.31853007602362",
# "accepatableConfidence":"9.065699348274535",
# "confidenceRates":[
# {
# "Jan":"9.938492883352197",
# "Feb":"5.186693666215575",
# "Mar":"1.6095710041333149",
# "Apr":"2.084309768101434",
# "May":"1.774625419630084",
# "Jun":"5.8339978133521555",
# "Jul":"5.094127404847441",
# "Aug":"7.194646512492611",
# "Sep":"8.271789744563549",
# "Oct":"12.352141864662755",
# "Nov":"19.876635294170597",
# "Dec":"29.571360803772706"
# }
# ]
# },
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1052.7619047619048",
# "idealConfidence":"7.182622748798204",
# "accepatableConfidence":"5.0198107956393905",
# "confidenceRates":[
# {
# "Jan":"1.40543798398501",
# "Feb":"2.7165305180855484",
# "Mar":"6.208363537874433",
# "Apr":"4.809764471552853",
# "May":"8.537539282596427",
# "Jun":"9.345434701957018",
# "Jul":"1.915466473671259",
# "Aug":"2.2857656759657488",
# "Sep":"6.459623480087444",
# "Oct":"5.847182037370899",
# "Nov":"6.291647663631451",
# "Dec":"4.414973720894594"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"768.6785714285714",
# "idealConfidence":"17.948156352606876",
# "accepatableConfidence":"11.089592312216658",
# "confidenceRates":[
# {
# "Jan":"10.806417289590172",
# "Feb":"10.574326979806855",
# "Mar":"11.932543525594852",
# "Apr":"24.806720392997093",
# "May":"7.958461940122433",
# "Jun":"15.729667473247787",
# "Jul":"10.029249758545589",
# "Aug":"13.166600482123073",
# "Sep":"7.253981408578184",
# "Oct":"15.40877535874877",
# "Nov":"3.479854832327291",
# "Dec":"1.9285083049177985"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"845.6785714285714",
# "idealConfidence":"10.43538698462331",
# "accepatableConfidence":"7.028734972495308",
# "confidenceRates":[
# {
# "Jan":"1.8765669831536513",
# "Feb":"6.053981818750216",
# "Mar":"9.632778088395426",
# "Apr":"7.791841879714369",
# "May":"12.497833241337503",
# "Jun":"13.842038996751313",
# "Jul":"9.056427220529002",
# "Aug":"3.556955482027064",
# "Sep":"5.508959180299328",
# "Oct":"1.600144316442183",
# "Nov":"5.403142668716768",
# "Dec":"7.524149793826879"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"459.32142857142856",
# "idealConfidence":"16.75731818241723",
# "accepatableConfidence":"11.13466356462517",
# "confidenceRates":[
# {
# "Jan":"16.979985355189598",
# "Feb":"22.379972800209288",
# "Mar":"21.027416008651826",
# "Apr":"19.74926383773149",
# "May":"11.752682834838922",
# "Jun":"6.419343728696134",
# "Jul":"1.9258817814747005",
# "Aug":"5.800808496389337",
# "Sep":"9.421979639177707",
# "Oct":"4.7028670102451855",
# "Nov":"7.5308971667932525",
# "Dec":"5.924864116104587"
# }
# ]
# },
# ]
# }
# {
# "QUEENS":
# [
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"1331.267857142857",
# "idealConfidence":"10.991619442673073",
# "accepatableConfidence":"6.032892975758833",
# "confidenceRates":[
# {
# "Jan":"2.162666035077038",
# "Feb":"1.4680569594184618",
# "Mar":"1.588579052149953",
# "Apr":"3.427806803808508",
# "May":"3.2343936438327177",
# "Jun":"4.4935619006758145",
# "Jul":"8.708476891626304",
# "Aug":"8.555674691417877",
# "Sep":"5.337528628683273",
# "Oct":"8.615756010536742",
# "Nov":"8.851869182291992",
# "Dec":"15.950345909587313"
# }
# ]
# },
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1093.482142857143",
# "idealConfidence":"7.969601338775705",
# "accepatableConfidence":"5.025049924304615",
# "confidenceRates":[
# {
# "Jan":"1.1360819602609098",
# "Feb":"1.6712247381913983",
# "Mar":"3.3062494053843636",
# "Apr":"3.425100491246539",
# "May":"7.493447473915026",
# "Jun":"10.914152753246796",
# "Jul":"9.300360057194396",
# "Aug":"5.228151672459333",
# "Sep":"9.189554970379476",
# "Oct":"4.39458636534674",
# "Nov":"3.14511915775941",
# "Dec":"1.0965700462709975"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"955.577380952381",
# "idealConfidence":"11.397168811787495",
# "accepatableConfidence":"8.073153193578746",
# "confidenceRates":[
# {
# "Jan":"7.295147448568315",
# "Feb":"8.299329084025644",
# "Mar":"11.315033972002752",
# "Apr":"14.721184429996242",
# "May":"8.766863408532998",
# "Jun":"10.900025734257682",
# "Jul":"9.397613810095592",
# "Aug":"10.068647870778662",
# "Sep":"1.346199831651532",
# "Oct":"3.9111590237719582",
# "Nov":"7.97495641038735",
# "Dec":"2.8816772988762267"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"877.4345238095239",
# "idealConfidence":"11.153408246874907",
# "accepatableConfidence":"8.027646702200377",
# "confidenceRates":[
# {
# "Jan":"1.9568325726498728",
# "Feb":"5.728091603045101",
# "Mar":"7.764578162219593",
# "Apr":"7.569524138459045",
# "May":"13.676284453185971",
# "Jun":"14.11886062552864",
# "Jul":"14.279169791549435",
# "Aug":"8.059737542969941",
# "Sep":"7.693770016487889",
# "Oct":"3.7963192387368423",
# "Nov":"5.782732226725415",
# "Dec":"5.905860054846784"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"677.0119047619048",
# "idealConfidence":"16.620574040859275",
# "accepatableConfidence":"8.058862779452298",
# "confidenceRates":[
# {
# "Jan":"6.323595340805213",
# "Feb":"6.329011318891091",
# "Mar":"2.9711857414803546",
# "Apr":"2.475793474385668",
# "May":"1.04714329848818",
# "Jun":"4.659298773653106",
# "Jul":"4.150086028043461",
# "Aug":"8.021098625218528",
# "Sep":"9.150586415944773",
# "Oct":"12.050426300283476",
# "Nov":"14.345842733967473",
# "Dec":"25.18228530226625"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"444.60714285714283",
# "idealConfidence":"14.024366504706496",
# "accepatableConfidence":"8.099794739953557",
# "confidenceRates":[
# {
# "Jan":"14.498358272230433",
# "Feb":"19.948938269459433",
# "Mar":"15.857100251573925",
# "Apr":"13.782843597975983",
# "May":"7.060387312548642",
# "Jun":"6.4779179063473435",
# "Jul":"1.0449240563135334",
# "Aug":"2.541892996157074",
# "Sep":"5.0453257128759645",
# "Oct":"4.029276260215653",
# "Nov":"2.0453068323188006",
# "Dec":"4.865265411425895"
# }
# ]
# },
# ]
# }
# {
# "STATEN":
# [
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"370.5892857142857",
# "idealConfidence":"14.510736472541836",
# "accepatableConfidence":"9.069863192849626",
# "confidenceRates":[
# {
# "Jan":"1.2669926741717745",
# "Feb":"3.492916928117367",
# "Mar":"6.169940519499988",
# "Apr":"10.78850552077266",
# "May":"15.18417311288944",
# "Jun":"19.95160975223405",
# "Jul":"11.442883870310808",
# "Aug":"3.713089743657548",
# "Sep":"16.758247607962446",
# "Oct":"11.503527659050178",
# "Nov":"5.063957915570342",
# "Dec":"3.5025130099589035"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"271.89285714285717",
# "idealConfidence":"12.676333864904912",
# "accepatableConfidence":"10.131673756376257",
# "confidenceRates":[
# {
# "Jan":"3.823228430244825",
# "Feb":"11.43002459322338",
# "Mar":"14.548894434663808",
# "Apr":"10.823581620657947",
# "May":"9.886813194107162",
# "Jun":"12.826172186866458",
# "Jul":"15.220993973433565",
# "Aug":"11.956137762826458",
# "Sep":"12.347690510102993",
# "Oct":"9.81463345603126",
# "Nov":"7.464978786127389",
# "Dec":"1.4369361282298456"
# }
# ]
# },
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"296.7797619047619",
# "idealConfidence":"15.600328614622125",
# "accepatableConfidence":"9.091399756276152",
# "confidenceRates":[
# {
# "Jan":"4.830716432203332",
# "Feb":"1.6572887425237042",
# "Mar":"2.4236124353478345",
# "Apr":"3.770077901060361",
# "May":"4.252712444330186",
# "Jun":"9.42076304471172",
# "Jul":"10.61006745198982",
# "Aug":"13.750665813046453",
# "Sep":"12.066587342341563",
# "Oct":"11.525780516271467",
# "Nov":"12.679267478519293",
# "Dec":"22.109257472968096"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"187.8452380952381",
# "idealConfidence":"15.096872267991438",
# "accepatableConfidence":"9.100973469289887",
# "confidenceRates":[
# {
# "Jan":"1.8640417972728613",
# "Feb":"2.266956354468576",
# "Mar":"10.966777056522986",
# "Apr":"14.751592518320223",
# "May":"21.09277106669299",
# "Jun":"16.814308503238166",
# "Jul":"9.718223205162317",
# "Aug":"5.900982463040776",
# "Sep":"10.195551873548098",
# "Oct":"6.709739453399351",
# "Nov":"4.34875703225056",
# "Dec":"4.581980307561736"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"143.57738095238096",
# "idealConfidence":"14.07869536142772",
# "accepatableConfidence":"9.135519446041213",
# "confidenceRates":[
# {
# "Jan":"15.23440503711548",
# "Feb":"19.021871276814224",
# "Mar":"14.939730011941222",
# "Apr":"13.443746797867249",
# "May":"10.523689541095465",
# "Jun":"7.307967775710054",
# "Jul":"6.211461367709731",
# "Aug":"7.159443521742006",
# "Sep":"5.125060007106086",
# "Oct":"7.703964391122511",
# "Nov":"1.468676474195064",
# "Dec":"1.4862171500754613"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"94.89285714285714",
# "idealConfidence":"20.07409026469886",
# "accepatableConfidence":"9.215287389185317",
# "confidenceRates":[
# {
# "Jan":"3.3347683921968923",
# "Feb":"1.1260714986365485",
# "Mar":"4.180494449934741",
# "Apr":"2.3472497429769135",
# "May":"3.930062708309734",
# "Jun":"1.9098745258367273",
# "Jul":"7.976437436110629",
# "Aug":"11.063443553190154",
# "Sep":"11.693078732480458",
# "Oct":"14.29174535590083",
# "Nov":"17.797329134437774",
# "Dec":"30.9328931402124"
# }
# ]
# },
# ]
# }
