# %%
import csv
import math
def areawise(freqfile,percentfile,P,A):
    csvfile = open(percentfile, newline='')
    csvAvg = open(freqfile,newline='')
    
    c = csv.reader(csvfile)
    d = csv.reader(csvAvg)
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    average=[0] * 71  # change to higher value to make it non-redundant for now it is equal to the no of total unique crimes
    i=0
    yearsToTrain = 14    # change s value to no of years to be used for training 
    
    for row in d:
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year' or row[0]=='month':
            continue
        else:
           j=0
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
                   average[i] += float(row[month])    # maintain grand average for scale later 
           if average[i] != 0:
                average[i] /= j
           i+=1
          
    percentages = []
    totals = []
    categories =[]
    i = 0
    monYear = []
    
    for row in c:
        
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year':
            continue
        elif row[0]=='month':
            for month in range(1,(yearsToTrain*12)+1):
                monYear.append(float(row[month]))
        else:
           temp = []
           categories.append(row[0])
           
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
               
               temp.append(float(row[month]))   # add monthly percentages of a particular crime to  list 
           
           percentages.append(temp)   # add monthly percentages list to a list 
           i += 1
    
    # print("percentages here :")
    # print(percentages)
    predictions=[]


    def predictOverYears(start,end):           # fn to give prediction for one year mentioned by start and end
        predictAyear = []
        for idx in range (0,i):
            crime = percentages[idx]
            sum =0
            index = -1
            for it in range (start,end):     # sum for caluclationg confidence later on             
                sum+=crime[it]
        
            predictMonth = []
    
            for it in range (start,end):
                avg = sum - crime[it]
                avg=float(avg/11)
                if avg != 0:
                    likeness = ((float(crime[it])/(avg))) * 100    # measure confidence rate for that month for that crime
                else :
                    likeness=0
                temp = [likeness,monYear[it]]
                predictMonth.append(temp)                   # append confidence rate and index of month predicted
    
            predictAyear.append(predictMonth)           # append all month's of that year likliness to a list 
        return predictAyear


    for j in range(0,yearsToTrain):            
        n=j*12
        predictions.append(predictOverYears(n,n+12))
    
    # print(predictions[1])
    # print("predictions here :")
    # print(predictions)
    
    predictionPerCrime = []
    for idx in range(0,i):
        tem = []
        for k in range(0,yearsToTrain):
            tem.append(predictions[k][idx])           # get each individual year predictions and add it to a new list 
        predictionPerCrime.append(tem)
        
    
    # print("prediction per crime:")
    # print(predictionPerCrime[0])


    grandPrediction = []
    for idx in range(0,i):
        perCrimeConf=[]
        for month in range(0,12):
            sumOverYears=0
            for yr in range(0,yearsToTrain):
                sumOverYears+=predictionPerCrime[idx][yr][month][0]
            tem=(  sumOverYears /  yearsToTrain )  # sum of confidence of a month across years and divide by yearsToTrain
            perCrimeConf.append(tem)
        grandPrediction.append(perCrimeConf)  # append confidence rates of each month per crime to list 

    
    
    # print(grandPrediction[0][2])
    
    for j in range(0,i):
        low=9999
        for m in range(0,12):
            if grandPrediction[j][m] < low:
                low = grandPrediction[j][m]
        if low != 0 :
             low = math.ceil(low) -2  # find lowest value ceil it and subtrat 2 from it
        for n in range(0,12):
            grandPrediction[j][n] -= low  # then subtract this val(low) from all
            grandPrediction[j][n] *= (math.sqrt(P)/A)
    
    # print("grand predictions: ")
    # print(grandPrediction)
    
    # for j in range(0,i):
    #     for k in range(0,12):
    #         grandPrediction[j][k] *= (math.sqrt(P)/A)

    print("{")
    print('\"'+freqfile.split('_')[0]+'\":')
    print("[")
    
    for j in range(0,6):
        print('{')
        print('\"'+"crime"+'\":'+'\"'+categories[j]+'\",')
        max = 0
        avg = 0
        for m in range (0,12):
             avg+=grandPrediction[j][m]
             if grandPrediction[j][m] > max :
                 max = grandPrediction[j][m]
        avg=avg/12
        ideal = ( max + avg)/2     # compute ideal confidence and acceptable confidence level
        print('\"'+"overallAverage"+'\":'+'\"'+str(average[j])+'\",')
        print('\"'+"idealConfidence"+'\":'+'\"'+str(ideal)+'\",')
        print('\"'+"accepatableConfidence"+'\":'+'\"'+str(avg)+'\",')
        print('\"'+"confidenceRates"+'\":'+'[')
        print('{')
        for k in range(0,12):
            if k != 11:
                print('\"'+months[k]+'\":'+'\"'+str(grandPrediction[j][k])+'\",')
            else:
                print('\"'+months[k]+'\":'+'\"'+str(grandPrediction[j][k])+'\"')
        # print(j+1,")",categories[j],"With overall average:",average[j])
        # print("With ideal confidence:",ideal,"and acceptable confidence:",avg,"monthly predictons are:")
        # for k in range(0,12):
        #     print("     Month",k+1,"confidence rate:",grandPrediction[j][k]) 
        print('}')  
        print(']')
        if j!=i-1:
            print('},')
        else:
            print('}')
                 
    print(']')
    print('}')


areawise('BRONX_Frequency.csv','BRONX_PercentageTotal.csv',1472654,109.3)
areawise('BROOKLYN_Frequency.csv','BROOKLYN_PercentageTotal.csv',2736074,179.7)
areawise('MANHATTAN_Frequency.csv','MANHATTAN_PercentageTotal.csv',1694251,58.8)
areawise('QUEENS_Frequency.csv','QUEENS_PercentageTotal.csv',2405464,281.5)
areawise('STATEN_ISLAND_Frequency.csv','STATEN_ISLAND_PercentageTotal.csv',495747,148.9)
# Out:
# {
# "BRONX":
# [
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1145.9345238095239",
# "idealConfidence":"98.76753336309454",
# "accepatableConfidence":"78.00332783718015",
# "confidenceRates":[
# {
# "Jan":"57.47340061803673",
# "Feb":"37.82745745523537",
# "Mar":"73.26212852558152",
# "Apr":"87.60330111148951",
# "May":"114.94340285538131",
# "Jun":"116.13697967489539",
# "Jul":"67.08003027548723",
# "Aug":"18.00402952651343",
# "Sep":"119.53173888900895",
# "Oct":"98.16813239576288",
# "Nov":"66.37836508237369",
# "Dec":"79.6309676363958"
# }
# ]
# },
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"1191.125",
# "idealConfidence":"157.91231859097573",
# "accepatableConfidence":"122.56751447084434",
# "confidenceRates":[
# {
# "Jan":"100.99543118861918",
# "Feb":"20.216826123020766",
# "Mar":"37.36221322310029",
# "Apr":"76.5815964475988",
# "May":"111.52950604077068",
# "Jun":"143.2269999976608",
# "Jul":"139.7744833331895",
# "Aug":"163.95315560899672",
# "Sep":"168.36680832744554",
# "Oct":"163.13770678038037",
# "Nov":"152.4083238682425",
# "Dec":"193.25712271110712"
# }
# ]
# },
# {
# "crime":"DANGEROUS DRUGS",
# "overallAverage":"928.0059523809524",
# "idealConfidence":"321.90262980008544",
# "accepatableConfidence":"223.80108600391478",
# "confidenceRates":[
# {
# "Jan":"334.22831990697375",
# "Feb":"420.00417359625607",
# "Mar":"307.3130144622227",
# "Apr":"270.4988112968405",
# "May":"200.73096889324887",
# "Jun":"116.68404613991693",
# "Jul":"140.84974879955283",
# "Aug":"250.8688793266883",
# "Sep":"247.80842140863072",
# "Oct":"221.27443767133983",
# "Nov":"154.15814042460002",
# "Dec":"21.19407012070669"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"1079.6964285714287",
# "idealConfidence":"102.59090546073233",
# "accepatableConfidence":"66.93123625564336",
# "confidenceRates":[
# {
# "Jan":"11.336426430479529",
# "Feb":"62.110487005149984",
# "Mar":"90.50479510804254",
# "Apr":"87.39521237408897",
# "May":"138.2505746658213",
# "Jun":"135.56587548319462",
# "Jul":"106.81358150318972",
# "Aug":"55.55277201839294",
# "Sep":"58.292932023891446",
# "Oct":"13.302402422657714",
# "Nov":"23.930832744979973",
# "Dec":"20.11894328783153"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"872.1904761904761",
# "idealConfidence":"99.30227790504739",
# "accepatableConfidence":"67.13470524062711",
# "confidenceRates":[
# {
# "Jan":"64.78134921289261",
# "Feb":"20.86012134704104",
# "Mar":"122.03840512115957",
# "Apr":"131.46985056946767",
# "May":"97.09667931926109",
# "Jun":"88.50019355488082",
# "Jul":"75.09008064733567",
# "Aug":"62.90748220894511",
# "Sep":"45.512641424111784",
# "Oct":"23.41513065231249",
# "Nov":"51.64524581029869",
# "Dec":"22.299283019818827"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"483.2440476190476",
# "idealConfidence":"158.55601655952984",
# "accepatableConfidence":"101.13906381805748",
# "confidenceRates":[
# {
# "Jan":"185.37098142883195",
# "Feb":"160.56526775835735",
# "Mar":"215.97296930100217",
# "Apr":"183.43420256327536",
# "May":"72.22376578667577",
# "Jun":"51.91306630618205",
# "Jul":"16.856020163121496",
# "Aug":"86.5110118728984",
# "Sep":"82.7145108852753",
# "Oct":"40.59121432409826",
# "Nov":"54.98610992543696",
# "Dec":"62.52964550153474"
# }
# ]
# },
# ]
# }
# {
# "BROOKLYN":
# [
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"1918.5654761904761",
# "idealConfidence":"128.824009303482",
# "accepatableConfidence":"101.58841965232881",
# "confidenceRates":[
# {
# "Jan":"76.77445950807252",
# "Feb":"10.387973287213793",
# "Mar":"24.48689247274777",
# "Apr":"56.633843344298924",
# "May":"88.41134983959316",
# "Jun":"127.3656501142069",
# "Jul":"156.05959895463522",
# "Aug":"150.8097973459303",
# "Sep":"129.35356311189716",
# "Oct":"126.45386446864339",
# "Nov":"122.69463020936826",
# "Dec":"149.62941317133823"
# }
# ]
# },
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1563.9107142857142",
# "idealConfidence":"67.1263247037479",
# "accepatableConfidence":"46.21544632592744",
# "confidenceRates":[
# {
# "Jan":"18.697996340273193",
# "Feb":"22.058236181329367",
# "Mar":"32.26403545221598",
# "Apr":"36.52285162425444",
# "May":"68.44408679969294",
# "Jun":"88.03720308156835",
# "Jul":"68.88975095567251",
# "Aug":"51.36640307206224",
# "Sep":"77.89353440609483",
# "Oct":"43.51227851275926",
# "Nov":"31.733877007437776",
# "Dec":"15.165102477768329"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"1355.3630952380952",
# "idealConfidence":"99.87426012510899",
# "accepatableConfidence":"64.73048871347257",
# "confidenceRates":[
# {
# "Jan":"26.96223919988678",
# "Feb":"45.84808617140134",
# "Mar":"84.78888050685043",
# "Apr":"69.94013303525321",
# "May":"127.93184529667957",
# "Jun":"135.0180315367454",
# "Jul":"116.08163232280857",
# "Aug":"65.99425685746333",
# "Sep":"57.19783647417194",
# "Oct":"16.74071286534877",
# "Nov":"9.884972645577577",
# "Dec":"20.37723764948383"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"1281.7559523809523",
# "idealConfidence":"90.64806389988519",
# "accepatableConfidence":"64.86240698058805",
# "confidenceRates":[
# {
# "Jan":"62.32287701977828",
# "Feb":"52.1369986920033",
# "Mar":"116.43372081918234",
# "Apr":"77.145331837777",
# "May":"74.53215413448441",
# "Jun":"81.58409253122647",
# "Jul":"88.54372495839146",
# "Aug":"40.14553127550214",
# "Sep":"43.24857641329676",
# "Oct":"53.08814612812194",
# "Nov":"79.0633396735951",
# "Dec":"10.104390283697377"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"951.1428571428571",
# "idealConfidence":"122.94139259725881",
# "accepatableConfidence":"83.25235661132619",
# "confidenceRates":[
# {
# "Jan":"51.2922138836073",
# "Feb":"10.252737993707086",
# "Mar":"17.78183016782186",
# "Apr":"25.590132255997347",
# "May":"36.10532714354216",
# "Jun":"91.94188461067426",
# "Jul":"119.58583707859758",
# "Aug":"110.1165225093182",
# "Sep":"109.55477959169055",
# "Oct":"123.16650962025044",
# "Nov":"141.01007589751617",
# "Dec":"162.63042858319142"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"656.0297619047619",
# "idealConfidence":"117.17669542624967",
# "accepatableConfidence":"74.56491865903571",
# "confidenceRates":[
# {
# "Jan":"127.0582922837065",
# "Feb":"154.2735754128185",
# "Mar":"159.78847219346363",
# "Apr":"151.92686509358137",
# "May":"80.60670828989991",
# "Jun":"33.88454152509011",
# "Jul":"27.13244179890307",
# "Aug":"35.97345828317847",
# "Sep":"32.38764866724224",
# "Oct":"12.525575584194973",
# "Nov":"35.95863989940826",
# "Dec":"43.26280487694144"
# }
# ]
# },
# ]
# }
# {
# "MANHATTAN":
# [
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"2174.8690476190477",
# "idealConfidence":"237.3380154671641",
# "accepatableConfidence":"177.58040067756278",
# "confidenceRates":[
# {
# "Jan":"116.11251308912331",
# "Feb":"72.90806023114503",
# "Mar":"34.63309818059329",
# "Apr":"98.75278820573286",
# "May":"124.2554375250474",
# "Jun":"204.56861341507513",
# "Jul":"257.0891742219212",
# "Aug":"297.09563025676545",
# "Sep":"276.4686654287285",
# "Oct":"176.7739555214879",
# "Nov":"191.14128084918565",
# "Dec":"281.1655912059474"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"1386.3869047619048",
# "idealConfidence":"427.64719486122607",
# "accepatableConfidence":"200.6840520727054",
# "confidenceRates":[
# {
# "Jan":"220.00476154180814",
# "Feb":"114.81593000258593",
# "Mar":"35.63048131192284",
# "Apr":"46.139598719091545",
# "May":"39.2842302001085",
# "Jun":"129.14506382672494",
# "Jul":"112.7668247209163",
# "Aug":"159.26524362762837",
# "Sep":"183.1095671784451",
# "Oct":"273.43482129144587",
# "Nov":"440.00176480204084",
# "Dec":"654.6103376497467"
# }
# ]
# },
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1052.7619047619048",
# "idealConfidence":"158.9990779931131",
# "accepatableConfidence":"111.12170527682025",
# "confidenceRates":[
# {
# "Jan":"31.111663725831363",
# "Feb":"60.1348369281995",
# "Mar":"137.43226017728162",
# "Apr":"106.47198705638468",
# "May":"188.99236695814858",
# "Jun":"206.87645070940596",
# "Jul":"42.40197681152171",
# "Aug":"50.59915405520481",
# "Sep":"142.99430910365132",
# "Oct":"129.43691814461818",
# "Nov":"139.27589023693415",
# "Dec":"97.73264941466108"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"768.6785714285714",
# "idealConfidence":"397.3117357748208",
# "accepatableConfidence":"245.4862262196617",
# "confidenceRates":[
# {
# "Jan":"239.21768489667156",
# "Feb":"234.07998707273143",
# "Mar":"264.1463271894271",
# "Apr":"549.1372453299799",
# "May":"176.17354481473686",
# "Jun":"348.2018634214259",
# "Jul":"222.0138131072269",
# "Aug":"291.4641921450667",
# "Sep":"160.57871839866544",
# "Oct":"341.09839270814905",
# "Nov":"77.03226651886952",
# "Dec":"42.69067903298929"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"845.6785714285714",
# "idealConfidence":"231.0043235020326",
# "accepatableConfidence":"155.59252088962816",
# "confidenceRates":[
# {
# "Jan":"41.54087309731978",
# "Feb":"134.01476884323526",
# "Mar":"213.23726556895988",
# "Apr":"172.48513782100025",
# "May":"276.6599377110307",
# "Jun":"306.416126114437",
# "Jul":"200.4787983911278",
# "Aug":"78.73901524334973",
# "Sep":"121.9498031573283",
# "Oct":"35.42180619367724",
# "Nov":"119.6073819601563",
# "Dec":"166.559336573916"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"459.32142857142856",
# "idealConfidence":"370.95058919631776",
# "accepatableConfidence":"246.48395195684415",
# "confidenceRates":[
# {
# "Jan":"375.87969050211353",
# "Feb":"495.4172264357914",
# "Mar":"465.4761742168171",
# "Apr":"437.18218971857334",
# "May":"260.16481723163594",
# "Jun":"142.10265106215365",
# "Jul":"42.63253664957513",
# "Aug":"128.41036412428096",
# "Sep":"208.5708978311299",
# "Oct":"104.10563727272556",
# "Nov":"166.70870068756216",
# "Dec":"131.15653774977025"
# }
# ]
# },
# ]
# }
# {
# "QUEENS":
# [
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"1331.267857142857",
# "idealConfidence":"60.55956057974811",
# "accepatableConfidence":"33.23890074088609",
# "confidenceRates":[
# {
# "Jan":"11.915451171511872",
# "Feb":"8.088424533992255",
# "Mar":"8.75245452648222",
# "Apr":"18.885886185705747",
# "May":"17.82025467985133",
# "Jun":"24.75778346968003",
# "Jul":"47.980330526028915",
# "Aug":"47.138449659564834",
# "Sep":"29.4077128507531",
# "Oct":"47.469474428377715",
# "Nov":"48.77036644007487",
# "Dec":"87.88022041861014"
# }
# ]
# },
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"1093.482142857143",
# "idealConfidence":"43.90941276571853",
# "accepatableConfidence":"27.686076368850078",
# "confidenceRates":[
# {
# "Jan":"6.2593710285195066",
# "Feb":"9.207800206578344",
# "Mar":"18.21615206034075",
# "Apr":"18.870975452997154",
# "May":"41.28598962277728",
# "Jun":"60.13274916258698",
# "Jul":"51.24137723605192",
# "Aug":"28.805088238336452",
# "Sep":"50.63088417790793",
# "Oct":"24.212466652723677",
# "Nov":"17.328386882227914",
# "Dec":"6.041675705153037"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"955.577380952381",
# "idealConfidence":"62.79398033154682",
# "accepatableConfidence":"44.47994332828001",
# "confidenceRates":[
# {
# "Jan":"40.1934333838552",
# "Feb":"45.72608477364526",
# "Mar":"62.34144921621898",
# "Apr":"81.10801733481362",
# "May":"48.302017591896934",
# "Jun":"60.0549147664141",
# "Jul":"51.77720769953779",
# "Aug":"55.4743451469318",
# "Sep":"7.417039016183532",
# "Oct":"21.548969473741572",
# "Nov":"43.93891713360223",
# "Dec":"15.876924402519125"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"877.4345238095239",
# "idealConfidence":"61.450954149211356",
# "accepatableConfidence":"44.22922020819991",
# "confidenceRates":[
# {
# "Jan":"10.781388615742948",
# "Feb":"31.55956337918803",
# "Mar":"42.779814570870286",
# "Apr":"41.70514254188874",
# "May":"75.35102367473927",
# "Jun":"77.78944675333348",
# "Jul":"78.6726880902228",
# "Aug":"44.40602829601402",
# "Sep":"42.3896891472834",
# "Oct":"20.91624679306004",
# "Nov":"31.860612026035874",
# "Dec":"32.53899861002004"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"677.0119047619048",
# "idealConfidence":"91.57291750748833",
# "accepatableConfidence":"44.40120868826505",
# "confidenceRates":[
# {
# "Jan":"34.84055803793138",
# "Feb":"34.87039797686858",
# "Mar":"16.370081209899034",
# "Apr":"13.640661931299674",
# "May":"5.769353492559628",
# "Jun":"25.670929367035207",
# "Jul":"22.865364611399194",
# "Aug":"44.19314284337379",
# "Sep":"50.416182554975855",
# "Oct":"66.39317575994365",
# "Nov":"79.040030147183",
# "Dec":"138.7446263267116"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"444.60714285714283",
# "idealConfidence":"77.26882079241801",
# "accepatableConfidence":"44.62672791721508",
# "confidenceRates":[
# {
# "Jan":"79.88033161749505",
# "Feb":"109.91091366762095",
# "Mar":"87.36647300361713",
# "Apr":"75.93812323890208",
# "May":"38.89999607435389",
# "Jun":"35.69081552778658",
# "Jul":"5.757126328799311",
# "Aug":"14.004844662869422",
# "Sep":"27.79778810092858",
# "Oct":"22.199749640688907",
# "Nov":"11.268847476205988",
# "Dec":"26.80572566731313"
# }
# ]
# },
# ]
# }
# {
# "STATEN":
# [
# {
# "crime":"HARRASSMENT 2",
# "overallAverage":"370.5892857142857",
# "idealConfidence":"68.61590640089042",
# "accepatableConfidence":"42.888028811430594",
# "confidenceRates":[
# {
# "Jan":"5.991139795425962",
# "Feb":"16.516712398388982",
# "Mar":"29.175366942000114",
# "Apr":"51.014852789836034",
# "May":"71.80033922195777",
# "Jun":"94.34378399035026",
# "Jul":"54.109166001825166",
# "Aug":"17.557828218506913",
# "Sep":"79.24355538306271",
# "Oct":"54.39592805141582",
# "Nov":"23.945584223814173",
# "Dec":"16.562088720583247"
# }
# ]
# },
# {
# "crime":"CRIMINAL MISCHIEF & RELATED OF",
# "overallAverage":"271.89285714285717",
# "idealConfidence":"59.94169487032184",
# "accepatableConfidence":"47.90893828630701",
# "confidenceRates":[
# {
# "Jan":"18.07863333575854",
# "Feb":"54.04835923611181",
# "Mar":"68.79634129214246",
# "Apr":"51.180714694308726",
# "May":"46.751083241959805",
# "Jun":"60.65022488149218",
# "Jul":"71.97445145433666",
# "Aug":"56.53615384736885",
# "Sep":"58.38766198473853",
# "Oct":"46.409771954195136",
# "Nov":"35.299123972294495",
# "Dec":"6.794739540976988"
# }
# ]
# },
# {
# "crime":"PETIT LARCENY",
# "overallAverage":"296.7797619047619",
# "idealConfidence":"73.76818468653077",
# "accepatableConfidence":"42.98986725519723",
# "confidenceRates":[
# {
# "Jan":"22.842671506613392",
# "Feb":"7.836705562907673",
# "Mar":"11.460366903536684",
# "Apr":"17.827304139436905",
# "May":"20.10950440608111",
# "Jun":"44.54730444068735",
# "Jul":"50.17108515274006",
# "Aug":"65.02181334236886",
# "Sep":"57.058429062301386",
# "Oct":"54.50115358363727",
# "Nov":"59.95556684419178",
# "Dec":"104.5465021178643"
# }
# ]
# },
# {
# "crime":"ASSAULT 3 & RELATED OFFENSES",
# "overallAverage":"187.8452380952381",
# "idealConfidence":"71.38752581213706",
# "accepatableConfidence":"43.03513780347729",
# "confidenceRates":[
# {
# "Jan":"8.814364297156693",
# "Feb":"10.719598231796164",
# "Mar":"51.857832953808696",
# "Apr":"69.75482556770811",
# "May":"99.73991382079682",
# "Jun":"79.50864662431486",
# "Jul":"45.95388353238915",
# "Aug":"27.9035637593917",
# "Sep":"48.21099427893165",
# "Oct":"31.727876471328713",
# "Nov":"20.56366374303323",
# "Dec":"21.666490361071695"
# }
# ]
# },
# {
# "crime":"OFF. AGNST PUB ORD SENSBLTY &",
# "overallAverage":"143.57738095238096",
# "idealConfidence":"66.5729437643875",
# "accepatableConfidence":"43.19849295170024",
# "confidenceRates":[
# {
# "Jan":"72.03786741479296",
# "Feb":"89.94739457707477",
# "Mar":"70.64445819781095",
# "Apr":"63.57050682474035",
# "May":"49.76263595650204",
# "Jun":"34.55667697002887",
# "Jul":"29.371703677894693",
# "Aug":"33.854360700429595",
# "Sep":"24.2345134178388",
# "Oct":"36.429198516376744",
# "Nov":"6.944827898794144",
# "Dec":"7.027771268119"
# }
# ]
# },
# {
# "crime":"GRAND LARCENY",
# "overallAverage":"94.89285714285714",
# "idealConfidence":"94.92294903790807",
# "accepatableConfidence":"43.575686054953444",
# "confidenceRates":[
# {
# "Jan":"15.768886458700043",
# "Feb":"5.324775671956029",
# "Mar":"19.768012218329332",
# "Apr":"11.099275971855993",
# "May":"18.583813127148165",
# "Jun":"9.03109032062122",
# "Jul":"37.717622779821134",
# "Aug":"52.31493306722937",
# "Sep":"55.29224497766499",
# "Oct":"67.5803783978494",
# "Nov":"84.15698764740293",
# "Dec":"146.2702120208627"
# }
# ]
# },
# ]
# }
