# %%
import csv
import math
def areawise(freqfile,percentfile):
    csvfile = open(percentfile, newline='')
    csvAvg = open(freqfile,newline='')
    
    c = csv.reader(csvfile)
    d = csv.reader(csvAvg)
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    average=[0] * 71  # change to higher value to make it non-redundant for now it is equal to the no of total unique crimes
    i=0
    yearsToTrain = 14    # change s value to no of years to be used for training 
    
    for row in d:
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year' or row[0]=='month':
            continue
        else:
           j=0
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
                   average[i] += float(row[month])    # maintain grand average for scale later 
           if average[i] != 0:
                average[i] /= j
           i+=1
          
    percentages = []
    totals = []
    categories =[]
    i = 0
    monYear = []
    
    for row in c:
        
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year':
            continue
        elif row[0]=='month':
            for month in range(1,(yearsToTrain*12)+1):
                monYear.append(float(row[month]))
        else:
           temp = []
           categories.append(row[0])
           
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
               
               temp.append(float(row[month]))   # add monthly percentages of a particular crime to  list 
           
           percentages.append(temp)   # add monthly percentages list to a list 
           i += 1
    
    predictions=[]


    def predictOverYears(start,end):           # fn to give prediction for one year mentioned by start and end
        predictAyear = []
        for idx in range (0,i):
            crime = percentages[idx]
            sum =0
            index = -1
            for it in range (start,end):     # sum for caluclationg confidence later on             
                sum+=crime[it]
        
            predictMonth = []
    
            for it in range (start,end):
                avg = sum - crime[it]
                avg=float(avg/11)
                if avg != 0:
                    likeness = ((float(crime[it])/(avg))) * 100    # measure confidence rate for that month for that crime
                else :
                    likeness=0
                temp = [likeness,monYear[it]]
                predictMonth.append(temp)                   # append confidence rate and index of month predicted
    
            predictAyear.append(predictMonth)           # append all month's of that year likliness to a list 
        return predictAyear


    for j in range(0,yearsToTrain):            
        n=j*12
        predictions.append(predictOverYears(n,n+12))
    
    # print(predictions[1])
    
    predictionPerCrime = []
    for idx in range(0,i):
        tem = []
        for k in range(0,yearsToTrain):
            tem.append(predictions[k][idx])           # get each individual year predictions and add it to a new list 
        predictionPerCrime.append(tem)
        
    # print(predictionPerCrime[0])



    grandPrediction = []
    for idx in range(0,i):
        perCrimeConf=[]
        for month in range(0,12):
            sumOverYears=0
            for yr in range(0,yearsToTrain):
                sumOverYears+=predictionPerCrime[idx][yr][month][0]
            tem=sumOverYears/yearsToTrain   # sum of confidence of a month across years and divide by yearsToTrain
            perCrimeConf.append(tem)
        grandPrediction.append(perCrimeConf)  # append confidence rates of each month per crime to list 

    
    
    # print(grandPrediction[0][2])
    
    for j in range(0,i):
        low=9999
        for m in range(0,12):
            if grandPrediction[j][m] < low:
                low = grandPrediction[j][m]
        if low != 0 :
             low = math.ceil(low) -2  # find lowest value ceil it and subtrat 2 from it
        for n in range(0,12):
            grandPrediction[j][n] -= low  # then subtract this val(low) from all
    
    print("{")
    # print('\"'+freqfile.split('_')[0]+'\":')
    # print("[")
    


    for j in range(0,i):
        
        print('\"'+categories[j]+'\":')
        print('[')
        print('{')
        
        max = 0
        avg = 0
        for m in range (0,12):
             avg+=grandPrediction[j][m]
             if grandPrediction[j][m] > max :
                 max = grandPrediction[j][m]
        avg=avg/12
        ideal = ( max + avg)/2     # compute ideal confidence and acceptable confidence level
        print('\"'+"overallAverage"+'\":'+str(average[j])+',')
        print('\"'+"idealConfidence"+'\":'+str(ideal)+',')
        print('\"'+"accepatableConfidence"+'\":'+str(avg)+',')
        print('\"'+"confidenceRates"+'\":'+'[')
        print('{')
        for k in range(0,12):
            if k != 11:
                print('\"'+months[k]+'\":'+str(grandPrediction[j][k])+',')
            else:
                print('\"'+months[k]+'\":'+str(grandPrediction[j][k]))
        # print(j+1,")",categories[j],"With overall average:",average[j])
        # print("With ideal confidence:",ideal,"and acceptable confidence:",avg,"monthly predictons are:")
        # for k in range(0,12):
        #     print("     Month",k+1,"confidence rate:",grandPrediction[j][k]) 
        print('}')  
        print(']')
        if j!=i-1:
            print('}],')
        else:
            print('}]')
                 
    # print(']')
    print('}')

# areawise('BRONX_Frequency.csv','BRONX_PercentageTotal.csv')
# areawise('BROOKLYN_Frequency.csv','BROOKLYN_PercentageTotal.csv')
# areawise('MANHATTAN_Frequency.csv','MANHATTAN_PercentageTotal.csv')
# areawise('QUEENS_Frequency.csv','QUEENS_PercentageTotal.csv')
areawise('STATEN_ISLAND_Frequency.csv','STATEN_ISLAND_PercentageTotal.csv')
# Out:
# {
# "HARRASSMENT 2":
# [
# {
# "overallAverage":370.5892857142857,
# "idealConfidence":14.510736472541836,
# "accepatableConfidence":9.069863192849626,
# "confidenceRates":[
# {
# "Jan":1.2669926741717745,
# "Feb":3.492916928117367,
# "Mar":6.169940519499988,
# "Apr":10.78850552077266,
# "May":15.18417311288944,
# "Jun":19.95160975223405,
# "Jul":11.442883870310808,
# "Aug":3.713089743657548,
# "Sep":16.758247607962446,
# "Oct":11.503527659050178,
# "Nov":5.063957915570342,
# "Dec":3.5025130099589035
# }
# ]
# }],
# "CRIMINAL MISCHIEF & RELATED OF":
# [
# {
# "overallAverage":271.89285714285717,
# "idealConfidence":12.676333864904912,
# "accepatableConfidence":10.131673756376257,
# "confidenceRates":[
# {
# "Jan":3.823228430244825,
# "Feb":11.43002459322338,
# "Mar":14.548894434663808,
# "Apr":10.823581620657947,
# "May":9.886813194107162,
# "Jun":12.826172186866458,
# "Jul":15.220993973433565,
# "Aug":11.956137762826458,
# "Sep":12.347690510102993,
# "Oct":9.81463345603126,
# "Nov":7.464978786127389,
# "Dec":1.4369361282298456
# }
# ]
# }],
# "PETIT LARCENY":
# [
# {
# "overallAverage":296.7797619047619,
# "idealConfidence":15.600328614622125,
# "accepatableConfidence":9.091399756276152,
# "confidenceRates":[
# {
# "Jan":4.830716432203332,
# "Feb":1.6572887425237042,
# "Mar":2.4236124353478345,
# "Apr":3.770077901060361,
# "May":4.252712444330186,
# "Jun":9.42076304471172,
# "Jul":10.61006745198982,
# "Aug":13.750665813046453,
# "Sep":12.066587342341563,
# "Oct":11.525780516271467,
# "Nov":12.679267478519293,
# "Dec":22.109257472968096
# }
# ]
# }],
# "ASSAULT 3 & RELATED OFFENSES":
# [
# {
# "overallAverage":187.8452380952381,
# "idealConfidence":15.096872267991438,
# "accepatableConfidence":9.100973469289887,
# "confidenceRates":[
# {
# "Jan":1.8640417972728613,
# "Feb":2.266956354468576,
# "Mar":10.966777056522986,
# "Apr":14.751592518320223,
# "May":21.09277106669299,
# "Jun":16.814308503238166,
# "Jul":9.718223205162317,
# "Aug":5.900982463040776,
# "Sep":10.195551873548098,
# "Oct":6.709739453399351,
# "Nov":4.34875703225056,
# "Dec":4.581980307561736
# }
# ]
# }],
# "OFF. AGNST PUB ORD SENSBLTY &":
# [
# {
# "overallAverage":143.57738095238096,
# "idealConfidence":14.07869536142772,
# "accepatableConfidence":9.135519446041213,
# "confidenceRates":[
# {
# "Jan":15.23440503711548,
# "Feb":19.021871276814224,
# "Mar":14.939730011941222,
# "Apr":13.443746797867249,
# "May":10.523689541095465,
# "Jun":7.307967775710054,
# "Jul":6.211461367709731,
# "Aug":7.159443521742006,
# "Sep":5.125060007106086,
# "Oct":7.703964391122511,
# "Nov":1.468676474195064,
# "Dec":1.4862171500754613
# }
# ]
# }],
# "GRAND LARCENY":
# [
# {
# "overallAverage":94.89285714285714,
# "idealConfidence":20.07409026469886,
# "accepatableConfidence":9.215287389185317,
# "confidenceRates":[
# {
# "Jan":3.3347683921968923,
# "Feb":1.1260714986365485,
# "Mar":4.180494449934741,
# "Apr":2.3472497429769135,
# "May":3.930062708309734,
# "Jun":1.9098745258367273,
# "Jul":7.976437436110629,
# "Aug":11.063443553190154,
# "Sep":11.693078732480458,
# "Oct":14.29174535590083,
# "Nov":17.797329134437774,
# "Dec":30.9328931402124
# }
# ]
# }],
# "DANGEROUS DRUGS":
# [
# {
# "overallAverage":80.67857142857143,
# "idealConfidence":30.219180050562436,
# "accepatableConfidence":20.51305901888089,
# "confidenceRates":[
# {
# "Jan":28.240334269032033,
# "Feb":39.925301082243976,
# "Mar":35.673667717972776,
# "Apr":29.08335239967927,
# "May":21.577760181771808,
# "Jun":15.295594372294573,
# "Jul":13.236801177350685,
# "Aug":9.36895263750229,
# "Sep":19.3123363830737,
# "Oct":20.357132237061336,
# "Nov":12.575218623242137,
# "Dec":1.5102571453461309
# }
# ]
# }],
# "INTOXICATED & IMPAIRED DRIVING":
# [
# {
# "overallAverage":52.535714285714285,
# "idealConfidence":21.1444764682608,
# "accepatableConfidence":13.347926668943563,
# "confidenceRates":[
# {
# "Jan":19.85940248287598,
# "Feb":28.94102626757804,
# "Mar":23.06221821270536,
# "Apr":11.005262548489128,
# "May":14.774543296681642,
# "Jun":4.423088643258708,
# "Jul":1.7804507190542154,
# "Aug":1.101106652938853,
# "Sep":7.1433238760663755,
# "Oct":13.576555846913578,
# "Nov":18.617288385417964,
# "Dec":15.89085309534289
# }
# ]
# }],
# "BURGLARY":
# [
# {
# "overallAverage":50.51190476190476,
# "idealConfidence":30.480942770541418,
# "accepatableConfidence":18.45191214349161,
# "confidenceRates":[
# {
# "Jan":14.611482171501692,
# "Feb":15.673321954910605,
# "Mar":8.739199962827868,
# "Apr":1.5708447995200459,
# "May":9.944234381797074,
# "Jun":5.866545893861058,
# "Jul":12.571715099742121,
# "Aug":28.064651694679483,
# "Sep":23.80988534144754,
# "Oct":28.1816551474208,
# "Nov":42.509973397591224,
# "Dec":29.87943587659983
# }
# ]
# }],
# "FELONY ASSAULT":
# [
# {
# "overallAverage":47.726190476190474,
# "idealConfidence":9.353697894338051,
# "accepatableConfidence":6.21982085134477,
# "confidenceRates":[
# {
# "Jan":4.457597609944244,
# "Feb":7.289378457601359,
# "Mar":7.829931451042327,
# "Apr":2.0524481467576408,
# "May":12.487574937331331,
# "Jun":5.911407022956979,
# "Jul":7.999659019025444,
# "Aug":1.286774043240598,
# "Sep":3.6888842853563375,
# "Oct":8.581734556790792,
# "Nov":6.419150207505012,
# "Dec":6.633310478585173
# }
# ]
# }],
# "GRAND LARCENY OF MOTOR VEHICLE":
# [
# {
# "overallAverage":26.827380952380953,
# "idealConfidence":27.58568374732493,
# "accepatableConfidence":20.55692972549483,
# "confidenceRates":[
# {
# "Jan":13.70761907726505,
# "Feb":19.917887604135544,
# "Mar":4.609318969220581,
# "Apr":1.8174266678363438,
# "May":11.660594851915576,
# "Jun":16.509978379953154,
# "Jul":31.071210676346396,
# "Aug":28.850492919529316,
# "Sep":30.99649209979262,
# "Oct":34.61443776915503,
# "Nov":25.586253943118706,
# "Dec":27.341443747669658
# }
# ]
# }],
# "THEFT-FRAUD":
# [
# {
# "overallAverage":26.642857142857142,
# "idealConfidence":42.263005372195735,
# "accepatableConfidence":22.81869894469594,
# "confidenceRates":[
# {
# "Jan":35.17975244945687,
# "Feb":61.70731179969553,
# "Mar":36.94352997856245,
# "Apr":26.872554253882853,
# "May":16.61030826172852,
# "Jun":17.466831016047507,
# "Jul":9.738357600619267,
# "Aug":9.12404608197032,
# "Sep":12.925527914349445,
# "Oct":1.7226304293385226,
# "Nov":21.579226417092926,
# "Dec":23.95431113360702
# }
# ]
# }],
# "OFFENSES AGAINST PUBLIC ADMINI":
# [
# {
# "overallAverage":52.779761904761905,
# "idealConfidence":23.60826105774009,
# "accepatableConfidence":19.28546243677099,
# "confidenceRates":[
# {
# "Jan":15.765130040304868,
# "Feb":18.287755571146633,
# "Mar":25.926512307006945,
# "Apr":27.93105967870919,
# "May":24.65539572239436,
# "Jun":20.536226327474495,
# "Jul":20.410726352796345,
# "Aug":1.7715976733467613,
# "Sep":24.40176970483411,
# "Oct":22.20280008675232,
# "Nov":19.94619426809375,
# "Dec":9.590381508392085
# }
# ]
# }],
# "ROBBERY":
# [
# {
# "overallAverage":34.160714285714285,
# "idealConfidence":31.318106445440158,
# "accepatableConfidence":21.40907261949522,
# "confidenceRates":[
# {
# "Jan":27.50711830154664,
# "Feb":1.1661955727446696,
# "Mar":9.736908358776603,
# "Apr":11.13409436043618,
# "May":12.242413709247828,
# "Jun":17.97762204718967,
# "Jul":21.62370243305645,
# "Aug":20.893160855716275,
# "Sep":23.851602136308202,
# "Oct":34.0173751389391,
# "Nov":41.227140271385096,
# "Dec":35.53153824859588
# }
# ]
# }],
# "DANGEROUS WEAPONS":
# [
# {
# "overallAverage":33.13095238095238,
# "idealConfidence":28.423869233156566,
# "accepatableConfidence":18.485848007956616,
# "confidenceRates":[
# {
# "Jan":38.36189045835651,
# "Feb":20.086714357537772,
# "Mar":25.646026927536766,
# "Apr":34.65884883450238,
# "May":26.520170028267515,
# "Jun":6.494281242635239,
# "Jul":10.987401134291915,
# "Aug":4.555903514297526,
# "Sep":18.394802181468307,
# "Oct":22.97148993567143,
# "Nov":11.620974719546865,
# "Dec":1.531672761367119
# }
# ]
# }],
# "MISCELLANEOUS PENAL LAW":
# [
# {
# "overallAverage":44.11904761904762,
# "idealConfidence":13.16113427220284,
# "accepatableConfidence":10.36333016930441,
# "confidenceRates":[
# {
# "Jan":11.755270581812411,
# "Feb":1.3043000963238995,
# "Mar":10.451378857680439,
# "Apr":10.60648262801783,
# "May":12.203223053923537,
# "Jun":14.059245738332379,
# "Jul":13.308788490573605,
# "Aug":4.714974227893578,
# "Sep":15.958938375101269,
# "Oct":11.82884469352473,
# "Nov":6.275353569219945,
# "Dec":11.893161719249292
# }
# ]
# }],
# "SEX CRIMES":
# [
# {
# "overallAverage":17.023809523809526,
# "idealConfidence":20.880929219510737,
# "accepatableConfidence":15.731117912664951,
# "confidenceRates":[
# {
# "Jan":1.6615676101585848,
# "Feb":21.07716964786077,
# "Mar":23.530329802166378,
# "Apr":16.948509573532434,
# "May":26.030740526356524,
# "Jun":16.3892323841893,
# "Jul":19.5262873234324,
# "Aug":5.332880535125042,
# "Sep":12.43184225541458,
# "Oct":25.39282696314436,
# "Nov":16.83525870578933,
# "Dec":3.6167696248096917
# }
# ]
# }],
# "FRAUDS":
# [
# {
# "overallAverage":21.291666666666668,
# "idealConfidence":31.219504053318936,
# "accepatableConfidence":18.760199744430683,
# "confidenceRates":[
# {
# "Jan":23.505806338101053,
# "Feb":24.59843373302148,
# "Mar":32.60646498729902,
# "Apr":43.67880836220719,
# "May":16.15533887169876,
# "Jun":17.40112511447687,
# "Jul":1.6895676280612406,
# "Aug":12.581697492180865,
# "Sep":14.670440318947982,
# "Oct":14.398239245312055,
# "Nov":18.036940013456174,
# "Dec":5.799534828405513
# }
# ]
# }],
# "UNAUTHORIZED USE OF A VEHICLE":
# [
# {
# "overallAverage":9.30952380952381,
# "idealConfidence":31.15110132674431,
# "accepatableConfidence":18.523864134668575,
# "confidenceRates":[
# {
# "Jan":25.070022717434924,
# "Feb":33.832950099710715,
# "Mar":2.700926313265853,
# "Apr":15.516720557534498,
# "May":1.4916204834200641,
# "Jun":13.756710630083418,
# "Jul":14.60361805964456,
# "Aug":37.20465756544202,
# "Sep":43.77833851882005,
# "Oct":7.092243235888077,
# "Nov":16.870473104194957,
# "Dec":10.36808833058376
# }
# ]
# }],
# "CRIMINAL TRESPASS":
# [
# {
# "overallAverage":11.886904761904763,
# "idealConfidence":25.646175247984935,
# "accepatableConfidence":20.83984890154703,
# "confidenceRates":[
# {
# "Jan":8.764829622518732,
# "Feb":27.532736270561728,
# "Mar":18.899270865470996,
# "Apr":23.302686395015414,
# "May":1.983314100258312,
# "Jun":27.812990088491503,
# "Jul":29.03380702509419,
# "Aug":27.220804396626065,
# "Sep":25.141086005043647,
# "Oct":15.533858384828335,
# "Nov":30.45250159442284,
# "Dec":14.400302070232598
# }
# ]
# }],
# "POSSESSION OF STOLEN PROPERTY":
# [
# {
# "overallAverage":8.203592814371257,
# "idealConfidence":33.60991672798725,
# "accepatableConfidence":21.1356297159024,
# "confidenceRates":[
# {
# "Jan":1.0129267089003235,
# "Feb":24.47544769050944,
# "Mar":46.0842037400721,
# "Apr":8.385276014812717,
# "May":21.835554197343754,
# "Jun":27.746501235753684,
# "Jul":14.821324870927668,
# "Aug":18.97074121314992,
# "Sep":15.501541340244941,
# "Oct":22.88079019348416,
# "Nov":35.25365867881388,
# "Dec":16.659590706816218
# }
# ]
# }],
# "RAPE":
# [
# {
# "overallAverage":4.650602409638554,
# "idealConfidence":42.313872074509625,
# "accepatableConfidence":30.15524474247128,
# "confidenceRates":[
# {
# "Jan":38.033376785761135,
# "Feb":54.47249940654797,
# "Mar":18.46900114079986,
# "Apr":26.87103851858589,
# "May":30.408863905340766,
# "Jun":30.18487336934848,
# "Jul":40.70664419011989,
# "Aug":1.8724228580988722,
# "Sep":33.8281730505047,
# "Oct":31.61122057637961,
# "Nov":26.914391855870377,
# "Dec":28.490431252297782
# }
# ]
# }],
# "ARSON":
# [
# {
# "overallAverage":5.672727272727273,
# "idealConfidence":55.7126690304253,
# "accepatableConfidence":32.77877483342729,
# "confidenceRates":[
# {
# "Jan":52.212696283930114,
# "Feb":41.12367207828838,
# "Mar":63.73676260935525,
# "Apr":13.174589813327003,
# "May":14.507976586036435,
# "Jun":30.048278926838947,
# "Jul":21.087786402880496,
# "Aug":17.57836243064601,
# "Sep":15.401793527096757,
# "Oct":1.0553508164531564,
# "Nov":78.64656322742331,
# "Dec":44.771465298851666
# }
# ]
# }],
# "VEHICLE AND TRAFFIC LAWS":
# [
# {
# "overallAverage":13.125,
# "idealConfidence":28.001736509079336,
# "accepatableConfidence":20.78373971089768,
# "confidenceRates":[
# {
# "Jan":13.813507590106639,
# "Feb":35.02511418320488,
# "Mar":10.370987100556135,
# "Apr":23.02914800164511,
# "May":20.562850542403638,
# "Jun":29.358892112363193,
# "Jul":1.9982329166415695,
# "Aug":14.95591276817079,
# "Sep":22.69222689904207,
# "Oct":18.116885469422783,
# "Nov":24.261385639954383,
# "Dec":35.219733307260995
# }
# ]
# }],
# "OFFENSES INVOLVING FRAUD":
# [
# {
# "overallAverage":2.9194630872483223,
# "idealConfidence":51.02465489613934,
# "accepatableConfidence":31.74534087163079,
# "confidenceRates":[
# {
# "Jan":1.3708526408153574,
# "Feb":29.455783358218767,
# "Mar":46.011327863771655,
# "Apr":70.30396892064789,
# "May":18.709504513338175,
# "Jun":32.07423190441419,
# "Jul":19.796872391629805,
# "Aug":31.594229760927774,
# "Sep":48.388413522606356,
# "Oct":56.97433010218566,
# "Nov":24.444066258338694,
# "Dec":1.8205092226751702
# }
# ]
# }],
# "OFFENSES AGAINST THE PERSON":
# [
# {
# "overallAverage":4.271084337349397,
# "idealConfidence":50.98774532921927,
# "accepatableConfidence":39.68568186661983,
# "confidenceRates":[
# {
# "Jan":45.09628619982415,
# "Feb":42.10849713580714,
# "Mar":4.514799173517858,
# "Apr":55.87375839913213,
# "May":55.103957829423166,
# "Jun":42.89343161853358,
# "Jul":62.289808791818714,
# "Aug":31.69669269481747,
# "Sep":38.207941352126085,
# "Oct":60.509993874294906,
# "Nov":1.5553511237222182,
# "Dec":36.37766420642053
# }
# ]
# }],
# "ADMINISTRATIVE CODE":
# [
# {
# "overallAverage":4.2317073170731705,
# "idealConfidence":45.901115911253925,
# "accepatableConfidence":30.47353922918634,
# "confidenceRates":[
# {
# "Jan":40.21129026287744,
# "Feb":39.87026354584282,
# "Mar":44.44416580466495,
# "Apr":17.025794357892366,
# "May":1.150528769423687,
# "Jun":15.783554178995502,
# "Jul":3.3014104980905614,
# "Aug":22.802930179907136,
# "Sep":61.328692593321506,
# "Oct":36.66224374325395,
# "Nov":38.27925396889604,
# "Dec":44.82234284707012
# }
# ]
# }],
# "FORGERY":
# [
# {
# "overallAverage":9.75,
# "idealConfidence":38.05189457014407,
# "accepatableConfidence":22.879094703135703,
# "confidenceRates":[
# {
# "Jan":39.078011712999555,
# "Feb":42.71504525532664,
# "Mar":53.224694437152436,
# "Apr":37.653543776667206,
# "May":21.4012146253621,
# "Jun":3.351426068061002,
# "Jul":21.489914233528708,
# "Aug":20.62768484998739,
# "Sep":1.2157770851792833,
# "Oct":14.983217288716219,
# "Nov":12.94119603789143,
# "Dec":5.867411066756404
# }
# ]
# }],
# "OTHER OFFENSES RELATED TO THEF":
# [
# {
# "overallAverage":4.012820512820513,
# "idealConfidence":72.01731702100612,
# "accepatableConfidence":42.579747676236956,
# "confidenceRates":[
# {
# "Jan":41.42496632183209,
# "Feb":52.351313689524886,
# "Mar":42.229231867481545,
# "Apr":46.85996674822566,
# "May":15.75460680686274,
# "Jun":101.45488636577528,
# "Jul":56.58074940225849,
# "Aug":20.264818514853488,
# "Sep":1.4643219222158024,
# "Oct":41.30408041498468,
# "Nov":29.060753472087384,
# "Dec":62.20727658874138
# }
# ]
# }],
# "NYS LAWS-UNCLASSIFIED FELONY":
# [
# {
# "overallAverage":2.9214285714285713,
# "idealConfidence":43.63153926849868,
# "accepatableConfidence":24.644565242333623,
# "confidenceRates":[
# {
# "Jan":1.653893648918725,
# "Feb":55.99657166768992,
# "Mar":40.40988213379424,
# "Apr":5.6869905420056455,
# "May":62.61851329466373,
# "Jun":28.889797848245763,
# "Jul":5.142843674873703,
# "Aug":34.07827942421896,
# "Sep":21.716735915080264,
# "Oct":21.333473292031087,
# "Nov":15.103382223582457,
# "Dec":3.1044192428988993
# }
# ]
# }],
# "ALCOHOLIC BEVERAGE CONTROL LAW":
# [
# {
# "overallAverage":1.8,
# "idealConfidence":110.17365083679421,
# "accepatableConfidence":50.57951005762674,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":100.73271036756016,
# "Mar":101.59767904548893,
# "Apr":32.7459022094143,
# "May":0.0,
# "Jun":93.42368427780278,
# "Jul":0.0,
# "Aug":61.28564758387756,
# "Sep":29.83665533199632,
# "Oct":169.76779161596167,
# "Nov":17.564050259419183,
# "Dec":0.0
# }
# ]
# }],
# "PETIT LARCENY OF MOTOR VEHICLE":
# [
# {
# "overallAverage":1.2962962962962963,
# "idealConfidence":138.06218007131469,
# "accepatableConfidence":88.2691105814992,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":10.982488503005346,
# "Mar":81.36818263013649,
# "Apr":104.52295083985067,
# "May":113.8049332038366,
# "Jun":154.00499278518404,
# "Jul":187.85524956113014,
# "Aug":113.04852064595346,
# "Sep":72.38794195820466,
# "Oct":83.11704092850702,
# "Nov":40.314242323236044,
# "Dec":97.82278359894602
# }
# ]
# }],
# "KIDNAPPING & RELATED OFFENSES":
# [
# {
# "overallAverage":1.390625,
# "idealConfidence":154.39580606789053,
# "accepatableConfidence":90.87421277409153,
# "confidenceRates":[
# {
# "Jan":126.05180773651426,
# "Feb":121.23065197264805,
# "Mar":93.6684549492399,
# "Apr":217.91739936168952,
# "May":71.36170022130555,
# "Jun":61.127803213692545,
# "Jul":72.84592749573514,
# "Aug":123.30688486839725,
# "Sep":1.8037441986174017,
# "Oct":123.01593053574746,
# "Nov":38.9349981389059,
# "Dec":39.22525059660542
# }
# ]
# }],
# "OFFENSES AGAINST PUBLIC SAFETY":
# [
# {
# "overallAverage":2.017543859649123,
# "idealConfidence":638.0907045252751,
# "accepatableConfidence":190.05915561975868,
# "confidenceRates":[
# {
# "Jan":1.39260007468671,
# "Feb":13.341722190777777,
# "Mar":109.77849819288556,
# "Apr":80.62906965559202,
# "May":156.9720912917148,
# "Jun":1086.1222534307915,
# "Jul":630.3788504420414,
# "Aug":167.4847948075529,
# "Sep":6.633612216048892,
# "Oct":6.269584158637585,
# "Nov":11.730489584722637,
# "Dec":9.976301391652232
# }
# ]
# }],
# "OTHER STATE LAWS":
# [
# {
# "overallAverage":1.3333333333333333,
# "idealConfidence":54.32793783276875,
# "accepatableConfidence":22.804926255773363,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":85.85094940976413,
# "Apr":32.030122368588444,
# "May":71.9091568607973,
# "Jun":0.0,
# "Jul":12.682039836782641,
# "Aug":0.0,
# "Sep":57.39967868456376,
# "Oct":0.0,
# "Nov":13.78716790878404,
# "Dec":0.0
# }
# ]
# }],
# "BURGLAR'S TOOLS":
# [
# {
# "overallAverage":1.2950819672131149,
# "idealConfidence":119.57147412125856,
# "accepatableConfidence":72.07209478820661,
# "confidenceRates":[
# {
# "Jan":8.20966605476002,
# "Feb":83.32045923398688,
# "Mar":1.8406564289780363,
# "Apr":24.380927450125824,
# "May":109.6909605222601,
# "Jun":94.2230744138781,
# "Jul":167.0708534543105,
# "Aug":95.11180346670693,
# "Sep":89.04493508093003,
# "Oct":111.3279971426326,
# "Nov":5.642867437412512,
# "Dec":75.0009367724979
# }
# ]
# }],
# "PROSTITUTION & RELATED OFFENSES":
# [
# {
# "overallAverage":1.1,
# "idealConfidence":107.28230318622427,
# "accepatableConfidence":25.494417211168116,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":28.035864041847702,
# "May":189.0701891612804,
# "Jun":25.95610607552543,
# "Jul":0.0,
# "Aug":62.870847255363856,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "OTHER STATE LAWS (NON PENAL LA":
# [
# {
# "overallAverage":2.0804597701149423,
# "idealConfidence":96.22715090150045,
# "accepatableConfidence":56.24088474390128,
# "confidenceRates":[
# {
# "Jan":25.80208370002309,
# "Feb":81.13424384830927,
# "Mar":91.94201506713179,
# "Apr":136.2134170590996,
# "May":53.89442698234066,
# "Jun":58.433360510525375,
# "Jul":23.675426157855483,
# "Aug":39.797146797910074,
# "Sep":85.54146556670091,
# "Oct":1.755482936692637,
# "Nov":66.5345534410975,
# "Dec":10.166994859128963
# }
# ]
# }],
# "FRAUDULENT ACCOSTING":
# [
# {
# "overallAverage":1.0909090909090908,
# "idealConfidence":134.07004671453592,
# "accepatableConfidence":42.71594336470093,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":90.77362166909082,
# "Mar":225.42415006437093,
# "Apr":39.21788547430172,
# "May":76.98225213411499,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":80.19341103453253,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "CHILD ABANDONMENT/NON SUPPORT":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":35.62603990858509,
# "accepatableConfidence":17.73166313070802,
# "confidenceRates":[
# {
# "Jan":53.52041668646216,
# "Feb":46.37777131142671,
# "Mar":16.73342278528421,
# "Apr":0.0,
# "May":15.042903349659017,
# "Jun":50.49999538010221,
# "Jul":15.261687612591585,
# "Aug":0.0,
# "Sep":15.34376044297038,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "OFFENSES RELATED TO CHILDREN":
# [
# {
# "overallAverage":1.8666666666666667,
# "idealConfidence":67.49500721720902,
# "accepatableConfidence":34.107173681406756,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":5.745020892061466,
# "Mar":16.33041404649263,
# "Apr":10.492369345217364,
# "May":96.25812562673637,
# "Jun":21.88603981683868,
# "Jul":82.00933942102525,
# "Aug":75.68193427549805,
# "Sep":100.88284075301128,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "NEW YORK CITY HEALTH CODE":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "UNLAWFUL POSS. WEAP. ON SCHOOL":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "LOITERING/GAMBLING (CARDS, DIC":
# [
# {
# "overallAverage":1.3333333333333333,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "ABORTION":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "GAMBLING":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":70.0956102721805,
# "accepatableConfidence":36.275259800573465,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":93.29832381766553,
# "Mar":0.0,
# "Apr":41.11225432109122,
# "May":103.91596074378754,
# "Jun":39.04678322100197,
# "Jul":71.09179866831894,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":86.83799683501634
# }
# ]
# }],
# "ESCAPE 3":
# [
# {
# "overallAverage":1.4,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "DISORDERLY CONDUCT":
# [
# {
# "overallAverage":2.210526315789474,
# "idealConfidence":742.7278410839064,
# "accepatableConfidence":139.00427098688394,
# "confidenceRates":[
# {
# "Jan":26.85062760748378,
# "Feb":59.247509287899355,
# "Mar":108.41988579582987,
# "Apr":19.109798979437382,
# "May":38.94283423604476,
# "Jun":25.08402926804833,
# "Jul":43.94515548693497,
# "Aug":0.0,
# "Sep":1346.4514111809287,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "ANTICIPATORY OFFENSES":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":48.05604482535964,
# "accepatableConfidence":13.114904745327836,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":82.99718490539145,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":74.38167203854259,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "ENDAN WELFARE INCOMP":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":14.60897885633687,
# "accepatableConfidence":8.188991766754569,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":21.028965945919172,
# "May":0.0,
# "Jun":18.979890233500843,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":18.67316371509045,
# "Oct":18.80735531969004,
# "Nov":20.778525986854333,
# "Dec":0.0
# }
# ]
# }],
# "HOMICIDE-NEGLIGENT-VEHICLE":
# [
# {
# "overallAverage":1.4285714285714286,
# "idealConfidence":49.905211308350076,
# "accepatableConfidence":11.042451754652895,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":88.76797086204726,
# "Mar":0.0,
# "Apr":14.91685887895345,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":14.081955330902371,
# "Oct":0.0,
# "Nov":14.742635983931649,
# "Dec":0.0
# }
# ]
# }],
# "HOMICIDE-NEGLIGENT,UNCLASSIFIE":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":51.408930489872745,
# "accepatableConfidence":13.208540171346414,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":68.89316124775787,
# "Dec":89.60932080839908
# }
# ]
# }],
# "UNDER THE INFLUENCE OF DRUGS":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "AGRICULTURE & MRKTS LAW-UNCLASSIFIED":
# [
# {
# "overallAverage":1.2941176470588236,
# "idealConfidence":50.54858205763894,
# "accepatableConfidence":33.83153461295574,
# "confidenceRates":[
# {
# "Jan":41.760899226672855,
# "Feb":19.989438931910463,
# "Mar":15.449336339081306,
# "Apr":16.588570676086928,
# "May":59.48355757989863,
# "Jun":31.043967417017043,
# "Jul":29.78380489566367,
# "Aug":57.67271870792401,
# "Sep":67.26562950232213,
# "Oct":23.948608210866134,
# "Nov":41.57520239128045,
# "Dec":1.4166814767451452
# }
# ]
# }],
# "NYS LAWS-UNCLASSIFIED VIOLATION":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "INTOXICATED/IMPAIRED DRIVING":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":46.43740215288315,
# "accepatableConfidence":13.096758902301397,
# "confidenceRates":[
# {
# "Jan":79.7780454034649,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":77.38306142415186,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "KIDNAPPING":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":55.92648294227047,
# "accepatableConfidence":13.4289352342873,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":98.42403065025364,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":62.72319216119395,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "DISRUPTION OF A RELIGIOUS SERV":
# [
# {
# "overallAverage":2.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "FELONY SEX CRIMES":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":46.3226507385197,
# "accepatableConfidence":13.096239329971331,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":77.6058098125879,
# "Dec":79.54906214706807
# }
# ]
# }]
# }

# %%
test = 'whatter_what'
test.split('_')[0]
freqfile='BROOKLYN_Frequency.csv'
print('\"'+freqfile.split('_')[0]+'\":')

print("{")
print('\"'+freqfile.split('_')[0]+'\":')
print("[")

areawise('BRONX_Frequency.csv','BRONX_PercentageTotal.csv')
areawise('BROOKLYN_Frequency.csv','BROOKLYN_PercentageTotal.csv')
areawise('MANHATTAN_Frequency.csv','MANHATTAN_PercentageTotal.csv')
areawise('QUEENS_Frequency.csv','QUEENS_PercentageTotal.csv')
areawise('STATEN_ISLAND_Frequency.csv','STATEN_ISLAND_PercentageTotal.csv')
# Out:
# "BROOKLYN":
