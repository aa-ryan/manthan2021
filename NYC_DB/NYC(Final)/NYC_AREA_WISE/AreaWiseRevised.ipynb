# %%
import csv
import math
def areawise(freqfile,percentfile):
    csvfile = open(percentfile, newline='')
    csvAvg = open(freqfile,newline='')
    
    c = csv.reader(csvfile)
    d = csv.reader(csvAvg)
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    average=[0] * 71  # change to higher value to make it non-redundant for now it is equal to the no of total unique crimes
    i=0
    yearsToTrain = 14    # change s value to no of years to be used for training 
    
    for row in d:
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year' or row[0]=='month':
            continue
        else:
           j=0
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
                   average[i] += float(row[month])    # maintain grand average for scale later 
           if average[i] != 0:
                average[i] /= j
           i+=1
          
    percentages = []
    totals = []
    categories =[]
    i = 0
    monYear = []
    
    for row in c:
        
        if row[0] == 'TOTAL'or row[0]=='Category' or row[0]=='year':
            continue
        elif row[0]=='month':
            for month in range(1,(yearsToTrain*12)+1):
                monYear.append(float(row[month]))
        else:
           temp = []
           categories.append(row[0])
           
           for month in range (1,(yearsToTrain*12)+1):
               if float(row[month]) !=0:    
                   j+=1
               
               temp.append(float(row[month]))   # add monthly percentages of a particular crime to  list 
           
           percentages.append(temp)   # add monthly percentages list to a list 
           i += 1
    
    predictions=[]


    def predictOverYears(start,end):           # fn to give prediction for one year mentioned by start and end
        predictAyear = []
        for idx in range (0,i):
            crime = percentages[idx]
            sum =0
            index = -1
            for it in range (start,end):     # sum for caluclationg confidence later on             
                sum+=crime[it]
        
            predictMonth = []
    
            for it in range (start,end):
                avg = sum - crime[it]
                avg=float(avg/11)
                if avg != 0:
                    likeness = ((float(crime[it])/(avg))) * 100    # measure confidence rate for that month for that crime
                else :
                    likeness=0
                temp = [likeness,monYear[it]]
                predictMonth.append(temp)                   # append confidence rate and index of month predicted
    
            predictAyear.append(predictMonth)           # append all month's of that year likliness to a list 
        return predictAyear


    for j in range(0,yearsToTrain):            
        n=j*12
        predictions.append(predictOverYears(n,n+12))
    
    # print(predictions[1])
    
    predictionPerCrime = []
    for idx in range(0,i):
        tem = []
        for k in range(0,yearsToTrain):
            tem.append(predictions[k][idx])           # get each individual year predictions and add it to a new list 
        predictionPerCrime.append(tem)
        
    # print(predictionPerCrime[0])



    grandPrediction = []
    for idx in range(0,i):
        perCrimeConf=[]
        for month in range(0,12):
            sumOverYears=0
            for yr in range(0,yearsToTrain):
                sumOverYears+=predictionPerCrime[idx][yr][month][0]
            tem=sumOverYears/yearsToTrain   # sum of confidence of a month across years and divide by yearsToTrain
            perCrimeConf.append(tem)
        grandPrediction.append(perCrimeConf)  # append confidence rates of each month per crime to list 

    
    
    # print(grandPrediction[0][2])
    
    for j in range(0,i):
        low=9999
        for m in range(0,12):
            if grandPrediction[j][m] < low:
                low = grandPrediction[j][m]
        if low != 0 :
             low = math.ceil(low) -2  # find lowest value ceil it and subtrat 2 from it
        for n in range(0,12):
            grandPrediction[j][n] -= low  # then subtract this val(low) from all
    
    print("{")
    # print('\"'+freqfile.split('_')[0]+'\":')
    # print("[")
    


    for j in range(0,i):
        
        print('\"'+categories[j]+'\":')
        print('[')
        print('{')
        
        max = 0
        avg = 0
        for m in range (0,12):
             avg+=grandPrediction[j][m]
             if grandPrediction[j][m] > max :
                 max = grandPrediction[j][m]
        avg=avg/12
        ideal = ( max + avg)/2     # compute ideal confidence and acceptable confidence level
        print('\"'+"overallAverage"+'\":'+str(average[j])+',')
        print('\"'+"idealConfidence"+'\":'+str(ideal)+',')
        print('\"'+"accepatableConfidence"+'\":'+str(avg)+',')
        print('\"'+"confidenceRates"+'\":'+'[')
        print('{')
        for k in range(0,12):
            if k != 11:
                print('\"'+months[k]+'\":'+str(grandPrediction[j][k])+',')
            else:
                print('\"'+months[k]+'\":'+str(grandPrediction[j][k]))
        # print(j+1,")",categories[j],"With overall average:",average[j])
        # print("With ideal confidence:",ideal,"and acceptable confidence:",avg,"monthly predictons are:")
        # for k in range(0,12):
        #     print("     Month",k+1,"confidence rate:",grandPrediction[j][k]) 
        print('}')  
        print(']')
        if j!=i-1:
            print('}],')
        else:
            print('}]')
                 
    # print(']')
    print('}')

areawise('BRONX_Frequency.csv','BRONX_PercentageTotal.csv')
# areawise('BROOKLYN_Frequency.csv','BROOKLYN_PercentageTotal.csv')
# areawise('MANHATTAN_Frequency.csv','MANHATTAN_PercentageTotal.csv')
# areawise('QUEENS_Frequency.csv','QUEENS_PercentageTotal.csv')
# areawise('STATEN_ISLAND_Frequency.csv','STATEN_ISLAND_PercentageTotal.csv')
# Out:
# {
# "HARRASSMENT 2":
# [
# {
# "overallAverage":1145.9345238095239,
# "idealConfidence":8.895779490453231,
# "accepatableConfidence":7.025592118516644,
# "confidenceRates":[
# {
# "Jan":5.17650569023499,
# "Feb":3.4070378063325535,
# "Mar":6.598562484788545,
# "Apr":7.890241082144712,
# "May":10.35270529562375,
# "Jun":10.460208194904226,
# "Jul":6.041754179988814,
# "Aug":1.6215842509570848,
# "Sep":10.765966862389817,
# "Oct":8.841792733366319,
# "Nov":5.97855670383926,
# "Dec":7.172190137629656
# }
# ]
# }],
# "PETIT LARCENY":
# [
# {
# "overallAverage":1191.125,
# "idealConfidence":14.222823200892229,
# "accepatableConfidence":11.039392645528805,
# "confidenceRates":[
# {
# "Jan":9.096441460113525,
# "Feb":1.8208860853705175,
# "Mar":3.365134258098095,
# "Apr":6.897539827386964,
# "May":10.045222945585792,
# "Jun":12.900148112177334,
# "Jul":12.589187355251838,
# "Aug":14.766908410072531,
# "Sep":15.164436626013895,
# "Oct":14.693462686380599,
# "Nov":13.72709022363891,
# "Dec":17.40625375625565
# }
# ]
# }],
# "DANGEROUS DRUGS":
# [
# {
# "overallAverage":928.0059523809524,
# "idealConfidence":28.993078136024014,
# "accepatableConfidence":20.15728289473207,
# "confidenceRates":[
# {
# "Jan":30.103226557524536,
# "Feb":37.82887337731596,
# "Mar":27.679022833872907,
# "Apr":24.363246664065713,
# "May":18.079407021483817,
# "Jun":10.509481295828621,
# "Jul":12.686034205190907,
# "Aug":22.595220873879057,
# "Sep":22.319572005755916,
# "Oct":19.92971310888069,
# "Nov":13.884692440724521,
# "Dec":1.9089043522621694
# }
# ]
# }],
# "ASSAULT 3 & RELATED OFFENSES":
# [
# {
# "overallAverage":1079.6964285714287,
# "idealConfidence":9.240142399320266,
# "accepatableConfidence":6.028352622361944,
# "confidenceRates":[
# {
# "Jan":1.0210475679751454,
# "Feb":5.5941580965808555,
# "Mar":8.151572411452307,
# "Apr":7.871498976724737,
# "May":12.45193217627859,
# "Jun":12.21012708999534,
# "Jul":9.620469756441011,
# "Aug":5.003518799465141,
# "Sep":5.250319122885813,
# "Oct":1.1981188009444708,
# "Nov":2.1553986808564503,
# "Dec":1.812069988743474
# }
# ]
# }],
# "CRIMINAL MISCHIEF & RELATED OF":
# [
# {
# "overallAverage":872.1904761904761,
# "idealConfidence":8.943942782245161,
# "accepatableConfidence":6.046678636609033,
# "confidenceRates":[
# {
# "Jan":5.834716916270295,
# "Feb":1.8788263038338897,
# "Mar":10.991736903395108,
# "Apr":11.841206927881288,
# "May":8.745289257189711,
# "Jun":7.971022257206883,
# "Jul":6.76320220434549,
# "Aug":5.665941741939761,
# "Sep":4.099225811872401,
# "Oct":2.1089505015517176,
# "Nov":4.651576310706361,
# "Dec":2.0084485031154884
# }
# ]
# }],
# "OFF. AGNST PUB ORD SENSBLTY &":
# [
# {
# "overallAverage":483.2440476190476,
# "idealConfidence":14.280799693690312,
# "accepatableConfidence":9.109378142397771,
# "confidenceRates":[
# {
# "Jan":16.695965957331097,
# "Feb":14.461768631529324,
# "Mar":19.45222124498285,
# "Apr":16.521524446815462,
# "May":6.505039384212054,
# "Jun":4.675698327256512,
# "Jul":1.5181855145305434,
# "Aug":7.791860937623127,
# "Sep":7.449918251892328,
# "Oct":3.655963448529633,
# "Nov":4.95248076244134,
# "Dec":5.63191080162899
# }
# ]
# }],
# "GRAND LARCENY":
# [
# {
# "overallAverage":480.38690476190476,
# "idealConfidence":18.62966055592159,
# "accepatableConfidence":12.082261534199572,
# "confidenceRates":[
# {
# "Jan":3.765846345727624,
# "Feb":1.3423413929074712,
# "Mar":3.866389867299759,
# "Apr":6.2526868116709835,
# "May":8.711490288688111,
# "Jun":10.712383117739577,
# "Jul":14.215594767056047,
# "Aug":19.07070856408913,
# "Sep":18.737173477305177,
# "Oct":15.549543894965169,
# "Nov":17.58592030530221,
# "Dec":25.177059577643604
# }
# ]
# }],
# "ROBBERY":
# [
# {
# "overallAverage":354.9345238095238,
# "idealConfidence":25.115804873701272,
# "accepatableConfidence":16.138906401315783,
# "confidenceRates":[
# {
# "Jan":22.483847573882613,
# "Feb":6.73833884896257,
# "Mar":1.197855426358359,
# "Apr":2.1604468613684276,
# "May":10.254065836142317,
# "Jun":9.859866745000886,
# "Jul":11.182341714058495,
# "Aug":16.665438253765473,
# "Sep":22.13560578819836,
# "Oct":29.13763119987918,
# "Nov":27.758735222086003,
# "Dec":34.092703346086765
# }
# ]
# }],
# "BURGLARY":
# [
# {
# "overallAverage":254.22619047619048,
# "idealConfidence":23.663639072217656,
# "accepatableConfidence":17.136366321906767,
# "confidenceRates":[
# {
# "Jan":23.356523333700565,
# "Feb":5.708536293575918,
# "Mar":1.2981675701796291,
# "Apr":3.8372771765295965,
# "May":10.883910972895109,
# "Jun":13.224679759577413,
# "Jul":19.293881557994467,
# "Aug":23.106382239678965,
# "Sep":29.458811341682306,
# "Oct":23.27989193157751,
# "Nov":21.997421862961204,
# "Dec":30.190911822528548
# }
# ]
# }],
# "FELONY ASSAULT":
# [
# {
# "overallAverage":423.5952380952381,
# "idealConfidence":18.573132890732314,
# "accepatableConfidence":12.074156327912297,
# "confidenceRates":[
# {
# "Jan":4.355731266417351,
# "Feb":1.4827579732879457,
# "Mar":8.23886902320426,
# "Apr":10.119333801027707,
# "May":17.574137447169818,
# "Jun":19.943081040617287,
# "Jul":25.07210945355233,
# "Aug":17.965961746831,
# "Sep":12.200186350100125,
# "Oct":7.1613382467159,
# "Nov":11.346946675463371,
# "Dec":9.429422910560461
# }
# ]
# }],
# "GRAND LARCENY OF MOTOR VEHICLE":
# [
# {
# "overallAverage":162.73809523809524,
# "idealConfidence":24.152520340206074,
# "accepatableConfidence":18.228046785357275,
# "confidenceRates":[
# {
# "Jan":17.744677406985573,
# "Feb":9.437719494652356,
# "Mar":1.79188616947188,
# "Apr":7.006314459474751,
# "May":13.694441623698168,
# "Jun":13.279311809784886,
# "Jul":21.763367398050804,
# "Aug":30.07699389505487,
# "Sep":26.58998920545477,
# "Oct":26.702761536941466,
# "Nov":21.092987062751618,
# "Dec":29.55611136196613
# }
# ]
# }],
# "CRIMINAL TRESPASS":
# [
# {
# "overallAverage":146.78571428571428,
# "idealConfidence":57.638037130096166,
# "accepatableConfidence":32.941394276766495,
# "confidenceRates":[
# {
# "Jan":80.03338738016024,
# "Feb":82.33467998342584,
# "Mar":65.97027273271553,
# "Apr":38.79273838271578,
# "May":30.5363977689354,
# "Jun":7.36259694135174,
# "Jul":1.4840842716131277,
# "Aug":9.689108545819977,
# "Sep":1.105816296248861,
# "Oct":20.843940501985585,
# "Nov":29.629162971950464,
# "Dec":27.514545544275393
# }
# ]
# }],
# "DANGEROUS WEAPONS":
# [
# {
# "overallAverage":272.5654761904762,
# "idealConfidence":28.69342481357735,
# "accepatableConfidence":18.22387213720121,
# "confidenceRates":[
# {
# "Jan":39.16297748995349,
# "Feb":36.31798418722663,
# "Mar":26.545409887558307,
# "Apr":27.457268910568516,
# "May":16.81720448813158,
# "Jun":7.740171887462992,
# "Jul":7.463012039541951,
# "Aug":14.258656338845483,
# "Sep":11.433666692519665,
# "Oct":15.763599095008871,
# "Nov":13.96235293084753,
# "Dec":1.7641616987495041
# }
# ]
# }],
# "MISCELLANEOUS PENAL LAW":
# [
# {
# "overallAverage":164.3154761904762,
# "idealConfidence":11.524724855449461,
# "accepatableConfidence":7.121902586912537,
# "confidenceRates":[
# {
# "Jan":8.988721401199271,
# "Feb":12.96081776248262,
# "Mar":15.927547123986386,
# "Apr":11.66766125277276,
# "May":3.2260390007703705,
# "Jun":4.8217149568705935,
# "Jul":9.374788909764675,
# "Aug":2.791407807638606,
# "Sep":4.440028168616507,
# "Oct":7.2504444550994975,
# "Nov":1.0384831546633677,
# "Dec":2.9751770490857865
# }
# ]
# }],
# "OFFENSES AGAINST PUBLIC ADMINI":
# [
# {
# "overallAverage":243.35714285714286,
# "idealConfidence":11.22378616617563,
# "accepatableConfidence":8.107130684184614,
# "confidenceRates":[
# {
# "Jan":3.6899999084862145,
# "Feb":9.137060439838038,
# "Mar":14.340441648166646,
# "Apr":8.959598818514664,
# "May":9.377427313681693,
# "Jun":8.440119128741244,
# "Jul":12.152699306158752,
# "Aug":9.507070993555857,
# "Sep":10.499954724383358,
# "Oct":6.9022969605449305,
# "Nov":1.4257743145694803,
# "Dec":2.853124653574497
# }
# ]
# }],
# "VEHICLE AND TRAFFIC LAWS":
# [
# {
# "overallAverage":122.76785714285714,
# "idealConfidence":18.07072110262847,
# "accepatableConfidence":11.186736759327369,
# "confidenceRates":[
# {
# "Jan":15.86189719620593,
# "Feb":24.954705445929577,
# "Mar":23.138976197724332,
# "Apr":13.290396775858326,
# "May":8.477124149024789,
# "Jun":4.906230775375988,
# "Jul":2.9302300822928373,
# "Aug":1.9588110580748577,
# "Sep":6.383256974512719,
# "Oct":9.503908907770168,
# "Nov":13.70775430387043,
# "Dec":9.127549245288463
# }
# ]
# }],
# "INTOXICATED & IMPAIRED DRIVING":
# [
# {
# "overallAverage":87.74404761904762,
# "idealConfidence":29.31795903910124,
# "accepatableConfidence":16.395768033583412,
# "confidenceRates":[
# {
# "Jan":15.62245193673651,
# "Feb":42.24015004461907,
# "Mar":34.57069615185833,
# "Apr":24.401306493260066,
# "May":12.088486159161974,
# "Jun":1.7799804020537238,
# "Jul":2.6979823487567245,
# "Aug":3.6629202729019,
# "Sep":9.699315451811827,
# "Oct":11.934492400320451,
# "Nov":23.68126352444321,
# "Dec":14.370171217077157
# }
# ]
# }],
# "SEX CRIMES":
# [
# {
# "overallAverage":91.375,
# "idealConfidence":18.984543484005833,
# "accepatableConfidence":11.164116726179001,
# "confidenceRates":[
# {
# "Jan":10.09845039433776,
# "Feb":14.822152434695028,
# "Mar":26.804970241832663,
# "Apr":15.560663703969652,
# "May":17.39621915026848,
# "Jun":10.431811734399986,
# "Jul":3.0263783073079793,
# "Aug":4.464182129272288,
# "Sep":7.96077034536286,
# "Oct":6.960077519012444,
# "Nov":15.202861047871792,
# "Dec":1.2408637058170768
# }
# ]
# }],
# "FORGERY":
# [
# {
# "overallAverage":71.86904761904762,
# "idealConfidence":32.528713899036674,
# "accepatableConfidence":18.373184138833608,
# "confidenceRates":[
# {
# "Jan":33.736408169010346,
# "Feb":40.739478424867926,
# "Mar":46.68424365923974,
# "Apr":16.221098236463362,
# "May":8.50117882143239,
# "Jun":1.6045686871406986,
# "Jul":8.688198785035823,
# "Aug":8.170726732259283,
# "Sep":6.314075197565344,
# "Oct":13.564950026879941,
# "Nov":20.58753515524964,
# "Dec":15.665747770858744
# }
# ]
# }],
# "THEFT-FRAUD":
# [
# {
# "overallAverage":71.9702380952381,
# "idealConfidence":38.852930696189716,
# "accepatableConfidence":20.58242995597772,
# "confidenceRates":[
# {
# "Jan":9.582919982958401,
# "Feb":53.49749937906881,
# "Mar":56.11604692463803,
# "Apr":57.12343143640172,
# "May":20.714501467057886,
# "Jun":15.829344272633975,
# "Jul":5.140665102434539,
# "Aug":10.814576801474985,
# "Sep":8.958714259060656,
# "Oct":4.298726113321408,
# "Nov":2.9526700243693824,
# "Dec":1.9600637083129016
# }
# ]
# }],
# "POSSESSION OF STOLEN PROPERTY":
# [
# {
# "overallAverage":40.00595238095238,
# "idealConfidence":18.72058135569925,
# "accepatableConfidence":13.434529775057802,
# "confidenceRates":[
# {
# "Jan":15.206712544930966,
# "Feb":12.408142072427353,
# "Mar":17.749210248947563,
# "Apr":24.006632936340694,
# "May":17.6024009187429,
# "Jun":8.703453813806647,
# "Jul":16.412345412482097,
# "Aug":13.763149048909128,
# "Sep":14.305919600784094,
# "Oct":13.413832110104565,
# "Nov":1.4361203274605288,
# "Dec":6.206438265757058
# }
# ]
# }],
# "ARSON":
# [
# {
# "overallAverage":27.738095238095237,
# "idealConfidence":48.89854531556706,
# "accepatableConfidence":28.901207074638794,
# "confidenceRates":[
# {
# "Jan":68.89588355649533,
# "Feb":62.573791603492595,
# "Mar":35.134976413492595,
# "Apr":21.793170054488883,
# "May":14.254938853928095,
# "Jun":1.553378117121369,
# "Jul":10.98780182858117,
# "Aug":11.16463560997228,
# "Sep":13.32172074894224,
# "Oct":31.88943265943935,
# "Nov":31.784714509082733,
# "Dec":43.4600409406289
# }
# ]
# }],
# "OTHER STATE LAWS (NON PENAL LA":
# [
# {
# "overallAverage":19.297619047619047,
# "idealConfidence":41.084011952275986,
# "accepatableConfidence":32.517072859507216,
# "confidenceRates":[
# {
# "Jan":42.88218483825605,
# "Feb":35.831972812479194,
# "Mar":33.015898617201515,
# "Apr":49.65095104504475,
# "May":26.851442037231394,
# "Jun":39.87570778149147,
# "Jul":45.01788756817007,
# "Aug":36.573264799400604,
# "Sep":35.073727457968275,
# "Oct":30.41621556213242,
# "Nov":14.00032331352142,
# "Dec":1.0152984811893901
# }
# ]
# }],
# "FRAUDS":
# [
# {
# "overallAverage":43.36309523809524,
# "idealConfidence":31.019381883235972,
# "accepatableConfidence":16.474889365075725,
# "confidenceRates":[
# {
# "Jan":33.049151441291784,
# "Feb":42.06324056013226,
# "Mar":45.56387440139622,
# "Apr":23.699436954691805,
# "May":6.271649756484379,
# "Jun":8.355570157832744,
# "Jul":7.339517510814787,
# "Aug":11.141381011215685,
# "Sep":2.492944668775621,
# "Oct":14.328265296955948,
# "Nov":1.2621267681905408,
# "Dec":2.1315138531269184
# }
# ]
# }],
# "OFFENSES INVOLVING FRAUD":
# [
# {
# "overallAverage":27.238095238095237,
# "idealConfidence":30.71526955468444,
# "accepatableConfidence":18.690781204298784,
# "confidenceRates":[
# {
# "Jan":42.73975790507009,
# "Feb":20.500586856545027,
# "Mar":26.192927052952584,
# "Apr":33.85089179026126,
# "May":4.750241620004303,
# "Jun":8.530205463190086,
# "Jul":5.313196233626712,
# "Aug":27.0004816872723,
# "Sep":20.058950696060307,
# "Oct":21.30391225908504,
# "Nov":12.706660075117625,
# "Dec":1.3415628123999994
# }
# ]
# }],
# "RAPE":
# [
# {
# "overallAverage":26.61904761904762,
# "idealConfidence":19.163915031500405,
# "accepatableConfidence":10.39895500133357,
# "confidenceRates":[
# {
# "Jan":13.23931873725249,
# "Feb":6.762755305899745,
# "Mar":27.92887506166724,
# "Apr":1.7249615234549367,
# "May":8.676774112670714,
# "Jun":12.218496574537639,
# "Jul":11.057401400073985,
# "Aug":20.149052925616772,
# "Sep":7.479970189818431,
# "Oct":5.871458492823905,
# "Nov":1.0075819175850427,
# "Dec":8.670813774601939
# }
# ]
# }],
# "UNAUTHORIZED USE OF A VEHICLE":
# [
# {
# "overallAverage":18.88095238095238,
# "idealConfidence":15.381840360586873,
# "accepatableConfidence":9.552856795682022,
# "confidenceRates":[
# {
# "Jan":3.795931720755803,
# "Feb":14.080054324257915,
# "Mar":13.408534085877747,
# "Apr":13.259311715689549,
# "May":11.509553927304651,
# "Jun":2.380135979603338,
# "Jul":5.903662101524105,
# "Aug":21.210823925491724,
# "Sep":8.569592775470696,
# "Oct":11.883011690081005,
# "Nov":6.962194183527373,
# "Dec":1.6714751186003554
# }
# ]
# }],
# "OFFENSES AGAINST THE PERSON":
# [
# {
# "overallAverage":27.470238095238095,
# "idealConfidence":78.7808203208549,
# "accepatableConfidence":40.24794423477628,
# "confidenceRates":[
# {
# "Jan":11.881047246114846,
# "Feb":15.026322818562633,
# "Mar":36.198409976590725,
# "Apr":56.10504687551408,
# "May":56.350080807780856,
# "Jun":64.53349756046184,
# "Jul":117.31369640693353,
# "Aug":44.604813061946246,
# "Sep":39.05573318135332,
# "Oct":25.578599753061695,
# "Nov":15.305841874657105,
# "Dec":1.0222412543384536
# }
# ]
# }],
# "ADMINISTRATIVE CODE":
# [
# {
# "overallAverage":19.363095238095237,
# "idealConfidence":24.268512480514303,
# "accepatableConfidence":16.706840861784528,
# "confidenceRates":[
# {
# "Jan":18.101801017656285,
# "Feb":14.057012100655427,
# "Mar":1.463880374292856,
# "Apr":2.76336012933686,
# "May":11.98624691821199,
# "Jun":21.37332721342618,
# "Jul":20.122089754642587,
# "Aug":28.21281786514119,
# "Sep":20.558212862524584,
# "Oct":31.83018409924408,
# "Nov":10.691318771303614,
# "Dec":19.321839234978697
# }
# ]
# }],
# "KIDNAPPING & RELATED OFFENSES":
# [
# {
# "overallAverage":4.208588957055214,
# "idealConfidence":38.4591200348228,
# "accepatableConfidence":25.856145366098758,
# "confidenceRates":[
# {
# "Jan":32.21808709741188,
# "Feb":15.496041790272358,
# "Mar":23.473893302527728,
# "Apr":29.807240091643962,
# "May":32.92556772537971,
# "Jun":11.348133797407286,
# "Jul":51.06209470354685,
# "Aug":17.132891311204077,
# "Sep":1.3699841829037354,
# "Oct":29.60207391890887,
# "Nov":35.701664547463935,
# "Dec":30.136071924514766
# }
# ]
# }],
# "NYS LAWS-UNCLASSIFIED FELONY":
# [
# {
# "overallAverage":9.095238095238095,
# "idealConfidence":31.624030563638094,
# "accepatableConfidence":18.344917210033056,
# "confidenceRates":[
# {
# "Jan":29.511372474929345,
# "Feb":44.90314391724313,
# "Mar":24.438739262363683,
# "Apr":26.232330126590412,
# "May":3.694553152051796,
# "Jun":7.274455926106569,
# "Jul":11.08066321758453,
# "Aug":1.8153307471088311,
# "Sep":31.311232657572376,
# "Oct":18.599497777766175,
# "Nov":12.872423053666836,
# "Dec":8.405264207413055
# }
# ]
# }],
# "OTHER OFFENSES RELATED TO THEF":
# [
# {
# "overallAverage":17.482142857142858,
# "idealConfidence":21.080286880558,
# "accepatableConfidence":11.767957738219735,
# "confidenceRates":[
# {
# "Jan":21.739289136975486,
# "Feb":30.392616022896263,
# "Mar":22.163106095484522,
# "Apr":6.843210433866787,
# "May":1.0763316880505869,
# "Jun":13.07653176734253,
# "Jul":4.6662795954161,
# "Aug":7.031001588550524,
# "Sep":1.7056978765454005,
# "Oct":5.492246434535318,
# "Nov":25.368708495864695,
# "Dec":1.6604737231086375
# }
# ]
# }],
# "ALCOHOLIC BEVERAGE CONTROL LAW":
# [
# {
# "overallAverage":3.513888888888889,
# "idealConfidence":81.8934590854705,
# "accepatableConfidence":45.24047809250226,
# "confidenceRates":[
# {
# "Jan":66.32130096189627,
# "Feb":118.54644007843874,
# "Mar":56.95021493135302,
# "Apr":56.334359262996216,
# "May":62.509963820151725,
# "Jun":12.872824111071381,
# "Jul":49.47233154174343,
# "Aug":1.401334090393071,
# "Sep":7.026011063053943,
# "Oct":33.30127645090353,
# "Nov":65.20220697415905,
# "Dec":12.947473823866773
# }
# ]
# }],
# "NEW YORK CITY HEALTH CODE":
# [
# {
# "overallAverage":1.1666666666666667,
# "idealConfidence":133.91126762051374,
# "accepatableConfidence":29.8376525843928,
# "confidenceRates":[
# {
# "Jan":237.98488265663468,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":37.9108618393228,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":82.15608651675609,
# "Dec":0.0
# }
# ]
# }],
# "CHILD ABANDONMENT/NON SUPPORT":
# [
# {
# "overallAverage":1.5376344086021505,
# "idealConfidence":103.15986112182992,
# "accepatableConfidence":58.43903340179404,
# "confidenceRates":[
# {
# "Jan":1.9275374604818083,
# "Feb":74.06121215911236,
# "Mar":4.279447562887903,
# "Apr":97.28406897720305,
# "May":25.08949422672997,
# "Jun":147.8806888418658,
# "Jul":120.12956131995227,
# "Aug":48.05882591341617,
# "Sep":39.94448081793682,
# "Oct":63.440744384752506,
# "Nov":40.56603999316992,
# "Dec":38.60629916402006
# }
# ]
# }],
# "GAMBLING":
# [
# {
# "overallAverage":5.0519480519480515,
# "idealConfidence":114.71647536332036,
# "accepatableConfidence":68.4905841344067,
# "confidenceRates":[
# {
# "Jan":37.6256327608326,
# "Feb":25.20515903338992,
# "Mar":25.841023601076238,
# "Apr":68.73963708782503,
# "May":75.21820074359941,
# "Jun":108.22988270704164,
# "Jul":71.22528081966315,
# "Aug":116.2227916020918,
# "Sep":160.942366592234,
# "Oct":74.00178616353837,
# "Nov":56.78105483698043,
# "Dec":1.8541936646079265
# }
# ]
# }],
# "PROSTITUTION & RELATED OFFENSES":
# [
# {
# "overallAverage":3.8253968253968256,
# "idealConfidence":89.29484884371281,
# "accepatableConfidence":51.70673800370286,
# "confidenceRates":[
# {
# "Jan":14.090519417142403,
# "Feb":34.998732776854496,
# "Mar":25.531593527723672,
# "Apr":1.3248746911309581,
# "May":75.27047940346861,
# "Jun":38.44093208386923,
# "Jul":23.603265331758067,
# "Aug":109.13047527999657,
# "Sep":102.27793337440991,
# "Oct":126.88295968372276,
# "Nov":36.86120999967193,
# "Dec":32.06788047468565
# }
# ]
# }],
# "OFFENSES AGAINST PUBLIC SAFETY":
# [
# {
# "overallAverage":3.032608695652174,
# "idealConfidence":554.9250439898213,
# "accepatableConfidence":123.98377565043164,
# "confidenceRates":[
# {
# "Jan":18.476485496196027,
# "Feb":45.823403978334255,
# "Mar":60.36667565837634,
# "Apr":12.072500596855456,
# "May":25.494132863711208,
# "Jun":210.50257788551394,
# "Jul":985.8663123292112,
# "Aug":18.49015638641645,
# "Sep":20.593609910934624,
# "Oct":30.14980887341823,
# "Nov":1.8696831278576802,
# "Dec":58.09996069835431
# }
# ]
# }],
# "LOITERING/GAMBLING (CARDS, DIC":
# [
# {
# "overallAverage":1.0769230769230769,
# "idealConfidence":132.41716602169453,
# "accepatableConfidence":39.352396509778444,
# "confidenceRates":[
# {
# "Jan":84.75957167060243,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":83.95106444911949,
# "Jul":0.0,
# "Aug":225.4819355336106,
# "Sep":0.0,
# "Oct":78.03618646400882,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "OFFENSES RELATED TO CHILDREN":
# [
# {
# "overallAverage":4.197916666666667,
# "idealConfidence":163.73696459226014,
# "accepatableConfidence":78.77208864744297,
# "confidenceRates":[
# {
# "Jan":248.70184053707732,
# "Feb":176.86656708913637,
# "Mar":134.12306896060264,
# "Apr":9.849105171187304,
# "May":45.369104602037325,
# "Jun":54.402578714652705,
# "Jul":16.922677911830995,
# "Aug":101.5938489734778,
# "Sep":60.670645931776235,
# "Oct":70.72552795009413,
# "Nov":24.976695164950613,
# "Dec":1.0634027624925153
# }
# ]
# }],
# "PETIT LARCENY OF MOTOR VEHICLE":
# [
# {
# "overallAverage":1.5686274509803921,
# "idealConfidence":80.98958447497556,
# "accepatableConfidence":55.210763906565056,
# "confidenceRates":[
# {
# "Jan":25.895367905564882,
# "Feb":44.394484956432535,
# "Mar":31.35039678562471,
# "Apr":56.44366943513401,
# "May":58.14580591445619,
# "Jun":57.68249904540099,
# "Jul":67.34231660230814,
# "Aug":106.76840504338605,
# "Sep":91.04320058631484,
# "Oct":85.67770145161518,
# "Nov":35.87142172302221,
# "Dec":1.91389742952083
# }
# ]
# }],
# "BURGLAR'S TOOLS":
# [
# {
# "overallAverage":2.486111111111111,
# "idealConfidence":51.64155362886242,
# "accepatableConfidence":30.12092239336972,
# "confidenceRates":[
# {
# "Jan":73.16218486435511,
# "Feb":22.385462521757972,
# "Mar":9.364546856613757,
# "Apr":29.19610027227847,
# "May":7.702754427735414,
# "Jun":27.955147315598907,
# "Jul":45.11071139667878,
# "Aug":58.713608665694125,
# "Sep":17.341195810344857,
# "Oct":41.05854120596912,
# "Nov":27.958437451307944,
# "Dec":1.5023779321022488
# }
# ]
# }],
# "FRAUDULENT ACCOSTING":
# [
# {
# "overallAverage":2.171171171171171,
# "idealConfidence":94.1000087448883,
# "accepatableConfidence":65.95999297932732,
# "confidenceRates":[
# {
# "Jan":29.34075039146957,
# "Feb":27.77770663210869,
# "Mar":1.7042028543218848,
# "Apr":98.25192765886251,
# "May":40.004024731214386,
# "Jun":31.73773439176034,
# "Jul":108.18960529664494,
# "Aug":88.32947075349662,
# "Sep":118.34568385359799,
# "Oct":96.92280977462627,
# "Nov":122.24002451044927,
# "Dec":28.67597490337546
# }
# ]
# }],
# "ANTICIPATORY OFFENSES":
# [
# {
# "overallAverage":1.0952380952380953,
# "idealConfidence":120.94052233579345,
# "accepatableConfidence":78.73856035604642,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":122.14501284627666,
# "Mar":161.18977864951543,
# "Apr":62.1715218985401,
# "May":163.14248431554046,
# "Jun":19.126238898444818,
# "Jul":48.509648553082215,
# "Aug":108.36527669111942,
# "Sep":19.30382248364941,
# "Oct":153.37218237220097,
# "Nov":87.53675756418758,
# "Dec":0.0
# }
# ]
# }],
# "INTOXICATED/IMPAIRED DRIVING":
# [
# {
# "overallAverage":1.1818181818181819,
# "idealConfidence":132.89440358162383,
# "accepatableConfidence":39.37128935637417,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":86.03617008452999,
# "Apr":83.68592199124912,
# "May":0.0,
# "Jun":226.4175178068735,
# "Jul":0.0,
# "Aug":76.31586239383738,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "OTHER STATE LAWS":
# [
# {
# "overallAverage":1.4210526315789473,
# "idealConfidence":285.7840932641859,
# "accepatableConfidence":97.26894183482204,
# "confidenceRates":[
# {
# "Jan":26.48770276215378,
# "Feb":20.82057974298764,
# "Mar":87.55712457727815,
# "Apr":165.2565580738229,
# "May":24.24827271664551,
# "Jun":38.019503735517105,
# "Jul":255.12970861949498,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":474.2992446935497,
# "Nov":42.12139634907299,
# "Dec":33.28721074734165
# }
# ]
# }],
# "JOSTLING":
# [
# {
# "overallAverage":1.1724137931034482,
# "idealConfidence":129.93612312569812,
# "accepatableConfidence":64.09225626721177,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":96.94978305636035,
# "Mar":0.0,
# "Apr":63.719603878840026,
# "May":72.58336607905044,
# "Jun":89.72137291306328,
# "Jul":45.352201462630546,
# "Aug":0.0,
# "Sep":50.59685447435579,
# "Oct":24.16692400367197,
# "Nov":130.23697935438446,
# "Dec":195.77998998418448
# }
# ]
# }],
# "LOITERING FOR DRUG PURPOSES":
# [
# {
# "overallAverage":1.75,
# "idealConfidence":270.06815117080976,
# "accepatableConfidence":61.29135339229672,
# "confidenceRates":[
# {
# "Jan":478.84494894932277,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":86.59852908645762,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":170.05276267178027
# }
# ]
# }],
# "HOMICIDE-NEGLIGENT,UNCLASSIFIE":
# [
# {
# "overallAverage":1.2333333333333334,
# "idealConfidence":187.76935599000402,
# "accepatableConfidence":101.24580445039317,
# "confidenceRates":[
# {
# "Jan":1.0016300631665196,
# "Feb":35.06691259872158,
# "Mar":144.7289713363651,
# "Apr":101.55251465793798,
# "May":41.74629325610643,
# "Jun":85.23259644319093,
# "Jul":274.29290752961487,
# "Aug":138.16326615954267,
# "Sep":17.418503292709865,
# "Oct":161.44679692458877,
# "Nov":83.65846121572996,
# "Dec":130.64079992704345
# }
# ]
# }],
# "ESCAPE 3":
# [
# {
# "overallAverage":1.391304347826087,
# "idealConfidence":156.0514729016119,
# "accepatableConfidence":109.77266659890655,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":124.85824522413604,
# "Mar":93.3812048877919,
# "Apr":183.78403652829215,
# "May":85.87562085992936,
# "Jun":202.33027920431724,
# "Jul":122.11636774968312,
# "Aug":173.42189301813946,
# "Sep":103.12428560384312,
# "Oct":146.5176692545239,
# "Nov":81.86239685622219,
# "Dec":0.0
# }
# ]
# }],
# "LOITERING/DEVIATE SEX":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":47.44669984206256,
# "accepatableConfidence":13.10577748693789,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":75.48170764606748,
# "Oct":0.0,
# "Nov":81.78762219718722,
# "Dec":0.0
# }
# ]
# }],
# "UNLAWFUL POSS. WEAP. ON SCHOOL":
# [
# {
# "overallAverage":1.0588235294117647,
# "idealConfidence":89.20781450726709,
# "accepatableConfidence":57.86699641442772,
# "confidenceRates":[
# {
# "Jan":120.54863260010646,
# "Feb":0.0,
# "Mar":107.81543406008923,
# "Apr":0.0,
# "May":101.49237150490707,
# "Jun":101.09867781285121,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":81.1385750563603,
# "Oct":76.08550413249064,
# "Nov":64.89645734162468,
# "Dec":41.32830446470306
# }
# ]
# }],
# "ADMINISTRATIVE CODES":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "ENDAN WELFARE INCOMP":
# [
# {
# "overallAverage":1.3255813953488371,
# "idealConfidence":129.89747978371523,
# "accepatableConfidence":76.76676932762913,
# "confidenceRates":[
# {
# "Jan":79.9320307786215,
# "Feb":22.799191744498913,
# "Mar":1.4272779393597084,
# "Apr":158.8438848700864,
# "May":73.24627967203894,
# "Jun":1.3505886228631816,
# "Jul":80.69691611146946,
# "Aug":119.66160792542087,
# "Sep":183.02819023980132,
# "Oct":8.058585812085504,
# "Nov":56.43410575881384,
# "Dec":135.72257245648987
# }
# ]
# }],
# "HOMICIDE-NEGLIGENT-VEHICLE":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":130.59470925935176,
# "accepatableConfidence":55.72220484373806,
# "confidenceRates":[
# {
# "Jan":205.46721367496545,
# "Feb":0.0,
# "Mar":38.31423177847718,
# "Apr":39.8257137475839,
# "May":0.0,
# "Jun":78.48836100292387,
# "Jul":38.61168916096309,
# "Aug":37.83338032358363,
# "Sep":39.72939862227041,
# "Oct":149.42671997097312,
# "Nov":40.96974984311606,
# "Dec":0.0
# }
# ]
# }],
# "THEFT OF SERVICES":
# [
# {
# "overallAverage":6.977099236641221,
# "idealConfidence":73.97230677773152,
# "accepatableConfidence":50.23873145789909,
# "confidenceRates":[
# {
# "Jan":69.39599123421674,
# "Feb":65.58602564134789,
# "Mar":1.3519463083545489,
# "Apr":97.70588209756394,
# "May":50.01421329211992,
# "Jun":8.183428803718257,
# "Jul":16.955986493243827,
# "Aug":58.1457483331055,
# "Sep":82.97418457024668,
# "Oct":77.50086414775267,
# "Nov":71.98169361026272,
# "Dec":3.0688129628564766
# }
# ]
# }],
# "DISRUPTION OF A RELIGIOUS SERV":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "LOITERING":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "DISORDERLY CONDUCT":
# [
# {
# "overallAverage":2.760869565217391,
# "idealConfidence":112.8224611593134,
# "accepatableConfidence":64.51071426143936,
# "confidenceRates":[
# {
# "Jan":52.37136969721716,
# "Feb":161.13420805718746,
# "Mar":1.61607394843206,
# "Apr":82.39343125965772,
# "May":64.09594534243827,
# "Jun":69.14962316568055,
# "Jul":45.207173244187985,
# "Aug":34.73959886513613,
# "Sep":95.07756725311404,
# "Oct":7.448454985670146,
# "Nov":55.42917736101231,
# "Dec":105.46594795753848
# }
# ]
# }],
# "OTHER STATE LAWS (NON PENAL LAW)":
# [
# {
# "overallAverage":1.5,
# "idealConfidence":90.06468392803266,
# "accepatableConfidence":16.76295898403848,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":37.78909893643492,
# "Jun":163.36640887202685,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "FORTUNE TELLING":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "OFFENSES AGAINST MARRIAGE UNCL":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "OTHER TRAFFIC INFRACTION":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "AGRICULTURE & MRKTS LAW-UNCLASSIFIED":
# [
# {
# "overallAverage":3.090909090909091,
# "idealConfidence":25.032040173090344,
# "accepatableConfidence":17.52451772059302,
# "confidenceRates":[
# {
# "Jan":6.490488420335414,
# "Feb":22.902855384632495,
# "Mar":1.764061052824939,
# "Apr":20.552428158323586,
# "May":3.0497851590359417,
# "Jun":13.001799871831238,
# "Jul":27.170859899307302,
# "Aug":24.09375107332398,
# "Sep":19.745997497754168,
# "Oct":32.53956262558766,
# "Nov":6.76292346901101,
# "Dec":32.21970003514848
# }
# ]
# }],
# "NYS LAWS-UNCLASSIFIED VIOLATION":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":60.98645519602851,
# "accepatableConfidence":31.27230241130123,
# "confidenceRates":[
# {
# "Jan":20.584273339108133,
# "Feb":22.581141349698978,
# "Mar":0.0,
# "Apr":19.33012743124608,
# "May":53.81941904740302,
# "Jun":56.33145030433944,
# "Jul":0.0,
# "Aug":68.06425585443641,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":90.70060798075579,
# "Dec":43.85635362862695
# }
# ]
# }],
# "KIDNAPPING":
# [
# {
# "overallAverage":1.5,
# "idealConfidence":153.94258572089856,
# "accepatableConfidence":43.82330926542246,
# "confidenceRates":[
# {
# "Jan":53.972484616438734,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":28.79703728928997,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":68.15137307434696,
# "Sep":264.0618621763747,
# "Oct":0.0,
# "Nov":110.89695402861912,
# "Dec":0.0
# }
# ]
# }],
# "ABORTION":
# [
# {
# "overallAverage":1.0,
# "idealConfidence":0.0,
# "accepatableConfidence":0.0,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":0.0,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":0.0,
# "Oct":0.0,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }],
# "FELONY SEX CRIMES":
# [
# {
# "overallAverage":1.3333333333333333,
# "idealConfidence":45.16559494207127,
# "accepatableConfidence":10.95038974155645,
# "confidenceRates":[
# {
# "Jan":0.0,
# "Feb":0.0,
# "Mar":0.0,
# "Apr":0.0,
# "May":0.0,
# "Jun":79.3808001425861,
# "Jul":0.0,
# "Aug":0.0,
# "Sep":25.911848640182537,
# "Oct":26.112028115908767,
# "Nov":0.0,
# "Dec":0.0
# }
# ]
# }]
# }

# %%
test = 'whatter_what'
test.split('_')[0]
freqfile='BROOKLYN_Frequency.csv'
print('\"'+freqfile.split('_')[0]+'\":')

print("{")
print('\"'+freqfile.split('_')[0]+'\":')
print("[")

areawise('BRONX_Frequency.csv','BRONX_PercentageTotal.csv')
areawise('BROOKLYN_Frequency.csv','BROOKLYN_PercentageTotal.csv')
areawise('MANHATTAN_Frequency.csv','MANHATTAN_PercentageTotal.csv')
areawise('QUEENS_Frequency.csv','QUEENS_PercentageTotal.csv')
areawise('STATEN_ISLAND_Frequency.csv','STATEN_ISLAND_PercentageTotal.csv')
# Out:
# "BROOKLYN":
